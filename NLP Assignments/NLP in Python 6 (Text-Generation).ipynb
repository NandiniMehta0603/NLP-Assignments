# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('C:/Users/Nandini/OneDrive/Desktop/NLP Assignments/pickle/corpus.pkl')
data
# Out:
#                                                 transcript         full_name
# ali      Ladies and gentlemen, please welcome to the st...          Ali Wong
# anthony  Thank you. Thank you. Thank you, San Francisco...  Anthony Jeselnik
# bill     [cheers and applause] All right, thank you! Th...         Bill Burr
# bo       Bo What? Old MacDonald had a farm E I E I O An...        Bo Burnham
# dave     This is Dave. He tells dirty jokes for a livin...    Dave Chappelle
# hasan    [theme music: orchestral hip-hop] [crowd roars...      Hasan Minhaj
# jim      [Car horn honks] [Audience cheering] [Announce...     Jim Jefferies
# joe      [rock music playing] [audience cheering] [anno...         Joe Rogan
# john     All right, Petunia. Wish me luck out there. Yo...      John Mulaney
# louis    Intro\nFade the music out. Let’s roll. Hold th...        Louis C.K.
# mike     Wow. Hey, thank you. Thanks. Thank you, guys. ...    Mike Birbiglia
# ricky    Hello. Hello! How you doing? Great. Thank you....     Ricky Gervais

# %%
# Extract only Ali Wong's text
ali_text = data.transcript.loc['ali']
ali_text[:200]
# Out:
# 'Ladies and gentlemen, please welcome to the stage: Ali Wong! Hi. Hello! Welcome! Thank you! Thank you for coming. Hello! Hello. We are gonna have to get this shit over with, ’cause I have to pee in, l'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(ali_text)
ali_dict
# Out:
# {'Ladies': ['and'],
#  'and': ['gentlemen,',
#   'foremost,',
#   'then',
#   'have',
#   'there’s',
#   'resentment',
#   'get',
#   'get',
#   'says,',
#   'my',
#   'she',
#   'snatch',
#   'running',
#   'fighting',
#   'yelling',
#   'it',
#   'she',
#   'I',
#   'I',
#   'I',
#   'we',
#   'watched',
#   'I',
#   'have',
#   'that',
#   'recycling,',
#   'disturbing',
#   'it’s',
#   'all',
#   'just…',
#   'be',
#   'half-Vietnamese.',
#   'his',
#   'slide.',
#   'your',
#   'inflamed',
#   'you’re',
#   'I',
#   'half-Japanese',
#   'I’m',
#   'half-Vietnamese.',
#   'playing',
#   'rugby.',
#   'foremost,',
#   'a',
#   'emotionally',
#   'I',
#   '20',
#   'neither',
#   'I',
#   'I–',
#   'then',
#   'it’s',
#   'find',
#   'start',
#   'just',
#   'caves',
#   'gets',
#   'is',
#   'very',
#   'for',
#   'I',
#   'she',
#   'rise',
#   'be',
#   'eat',
#   'watch',
#   'be',
#   'now',
#   'most',
#   'in',
#   'then',
#   'digitally',
#   'then',
#   'then',
#   'then',
#   'steady',
#   'brings',
#   'let',
#   'reverberate',
#   'say,',
#   'my',
#   'he',
#   'when',
#   'I’m',
#   'sicker,',
#   'sicker.',
#   'sicker,',
#   'sicker,',
#   'posted',
#   'that’s',
#   'lies.',
#   'as',
#   'treat',
#   'you’ll',
#   'succeed,',
#   'they',
#   'that’s',
#   'be',
#   'just',
#   'sisters.',
#   'a',
#   'unusual',
#   'they’ll',
#   'boring.”',
#   'wearing',
#   'famous',
#   'you’re',
#   'just',
#   'therefore,',
#   'ignore',
#   'the',
#   'Biggie',
#   'your',
#   'there',
#   'I',
#   'Push',
#   'then,',
#   'melt',
#   'I',
#   'then',
#   'sniff',
#   'I',
#   'you’ve',
#   'outside',
#   'as',
#   'rapey',
#   'most',
#   'see',
#   'I’d',
#   'I',
#   'he',
#   'instead',
#   'remember',
#   'hold',
#   'I',
#   'do',
#   'to',
#   'a',
#   'terrible.',
#   'I',
#   'when',
#   'I',
#   'held',
#   'got',
#   'I',
#   'your',
#   'he',
#   'I',
#   'leaves',
#   'dark.',
#   'naked,',
#   'a',
#   'my',
#   'then',
#   'recently',
#   'a'],
#  'gentlemen,': ['please'],
#  'please': ['welcome'],
#  'welcome': ['to'],
#  'to': ['the',
#   'get',
#   'pee',
#   'sleep,',
#   'sleep.',
#   'have',
#   'take',
#   'calm',
#   'sleep',
#   'declutter',
#   'achieve',
#   'help',
#   'a',
#   'let',
#   'buy',
#   'clean',
#   'be',
#   'Deepak-Oprah,',
#   'achieve',
#   'trap',
#   'date',
#   'any',
#   'cool',
#   'be',
#   'go',
#   'say',
#   'a',
#   'be',
#   'do',
#   'private',
#   'this',
#   'see',
#   'leave',
#   'private',
#   'backpack',
#   'do',
#   'shut',
#   'go',
#   'be',
#   'do',
#   'incept',
#   'leave',
#   'go',
#   'my',
#   'send',
#   'him',
#   'be',
#   'sit',
#   'the',
#   'lie',
#   'women.',
#   'be',
#   'continue',
#   'do',
#   'have',
#   'show',
#   'work.',
#   'earn',
#   'shit',
#   'seat.',
#   'eat',
#   'pull',
#   'ration',
#   'try',
#   'make',
#   'moisten',
#   'come',
#   'start',
#   'make',
#   'just',
#   'the',
#   'podcasts.',
#   'me',
#   'come',
#   'me',
#   'get',
#   'work',
#   'eat',
#   'tell',
#   'get',
#   'you',
#   'make',
#   'fuck',
#   'marry',
#   'turn',
#   'you.\nI',
#   'put',
#   'do',
#   'help',
#   'show',
#   'spank',
#   'abuse',
#   'be',
#   'be',
#   'do.',
#   'her,',
#   'use',
#   'say,',
#   'get',
#   'the',
#   'take',
#   'see',
#   'think',
#   'heal',
#   'me.',
#   'me',
#   'live',
#   'die.',
#   'hide',
#   'alert',
#   'have',
#   'keep',
#   'go.',
#   'be',
#   'support',
#   'be',
#   'the',
#   'protect',
#   'see',
#   'have',
#   'show',
#   'be.',
#   'get',
#   'get',
#   'take',
#   'act',
#   'find',
#   'discretely',
#   'immediately',
#   'be',
#   'smell',
#   'protect',
#   'see',
#   'have',
#   'get',
#   'save',
#   'be',
#   'close',
#   'shut',
#   'see',
#   'finish,',
#   'finish.',
#   'come',
#   'make',
#   'be',
#   'be…',
#   'be',
#   'me,',
#   'do',
#   'do',
#   'see',
#   'hire',
#   'Keyser',
#   'freak',
#   'freak',
#   'it.”',
#   'cleanse.',
#   'assist',
#   'make',
#   'do',
#   'be',
#   'be',
#   'all',
#   'all',
#   'go',
#   'those',
#   'see',
#   'chip',
#   'keep',
#   'get',
#   'protect',
#   'trap',
#   'propose',
#   'me.',
#   'Harvard'],
#  'the': ['stage:',
#   'light',
#   'chatter',
#   'kind',
#   'kind',
#   'presence',
#   'center',
#   'hoarding',
#   'HPV',
#   'country',
#   'third',
#   'Communists.\nThe',
#   'worst',
#   'calculator',
#   'future.',
#   'Tesla',
#   'manual',
#   'way',
#   'lucky',
#   'outside,',
#   'inside.',
#   'first',
#   'time,',
#   'fifth',
#   'back',
#   'park.”',
#   'middle',
#   'money',
#   'colonizer!”',
#   'time.',
#   'sexiest.',
#   'sexiest.',
#   'neck',
#   'last',
#   'rug',
#   'umami',
#   'difference.',
#   'Chinese,',
#   'Japanese.',
#   'East',
#   'west',
#   'name,',
#   'bathroom.',
#   'bathroom',
#   'corner.',
#   'wait',
#   'wall…',
#   'fuck',
#   'house.',
#   'idea',
#   'man’s',
#   'message,',
#   'whole',
#   'shit',
#   'fuck',
#   'woman',
#   'exact',
#   'following',
#   'goodness',
#   'C.O.O.',
#   'table',
#   'top.',
#   'fuck',
#   'worst',
#   'smart',
#   'next',
#   'secret.”',
#   'phrase,',
#   'street.',
#   'Boat',
#   'best',
#   'desert.',
#   'stall.',
#   'end',
#   'day',
#   'Goonies.',
#   'velocity',
#   'butt',
#   'doo',
#   'toilet',
#   'ends',
#   'toilet.',
#   'toilet',
#   'other',
#   'nerve',
#   'same',
#   'rest',
#   'promise',
#   'Internet',
#   'back.',
#   'Internet',
#   'Jewish',
#   'universe',
#   'pain.”',
#   'pain.',
#   'pain.',
#   'dick.',
#   'butt,',
#   'tush-tush.',
#   'man',
#   'look',
#   'man’s',
#   'first',
#   'woman,',
#   'Lord',
#   'Rim,',
#   'most',
#   'most',
#   'woman',
#   'time,',
#   'boss.',
#   'boss',
#   'time,',
#   'bedroom,',
#   'boss.',
#   'real',
#   'word',
#   'word',
#   'right',
#   'point',
#   'kind',
#   'case',
#   'audience',
#   'mom',
#   'fucking',
#   'baby’s',
#   'dream.”',
#   'point.',
#   'ultimate',
#   'world',
#   'rest',
#   'Galapagos,',
#   'phrase',
#   'women,',
#   'side',
#   'hood,',
#   'movie,',
#   'park,',
#   'sun.',
#   'sun',
#   'Tupac',
#   'time?',
#   'time,',
#   'peace',
#   'pill',
#   'progesterone',
#   'conference',
#   'urge',
#   'hood.',
#   'eggs',
#   'month,',
#   "Kraken!'”",
#   'time,',
#   'smiley',
#   'ovulation',
#   'time,',
#   'image',
#   'back',
#   'expression',
#   'fuck',
#   'indication',
#   'eye',
#   'shit',
#   'doctor',
#   'size',
#   'twins',
#   'toilet,',
#   'whole',
#   'fuck',
#   'marriage',
#   'pain',
#   'table?”',
#   'labor',
#   'floor',
#   'love',
#   'real',
#   'baby',
#   'house.',
#   'dishes?”',
#   'plants?”',
#   'channel.”',
#   'star',
#   'show.',
#   'camera',
#   'hero',
#   'baby',
#   'baby',
#   'kind',
#   'baby',
#   'same.',
#   'escrow',
#   'one',
#   'epicenter'],
#  'stage:': ['Ali'],
#  'Ali': ['Wong!', 'Wong.'],
#  'Wong!': ['Hi.'],
#  'Hi.': ['Hello!'],
#  'Hello!': ['Welcome!', 'Hello.'],
#  'Welcome!': ['Thank'],
#  'Thank': ['you!', 'you', 'you,', 'you.'],
#  'you!': ['Thank'],
#  'you': ['for',
#   'don’t',
#   'go',
#   'can',
#   'never',
#   'better',
#   'under',
#   'might',
#   'die.”',
#   'wanna',
#   'gotta',
#   'a',
#   'drop',
#   'know,',
#   'know,',
#   'feel',
#   'know.',
#   'know,',
#   'about',
#   'to',
#   'know,',
#   'right',
#   'get',
#   'like!',
#   'know?\nMy',
#   'know?',
#   'know,',
#   'can',
#   'eat',
#   'queef',
#   'know,',
#   'know',
#   'marry',
#   'something.',
#   'would',
#   'don’t',
#   'know',
#   'know',
#   'have',
#   'could',
#   'can',
#   'always',
#   'hurry,',
#   'never',
#   'dare',
#   'know,',
#   'deep,',
#   'not',
#   'guys',
#   'wanna',
#   'guys',
#   'telling',
#   'son',
#   'start',
#   'crave',
#   'realize',
#   'know…',
#   'now.',
#   'gotta',
#   'don’t',
#   'put',
#   'know?',
#   'haven’t',
#   'know,',
#   'stick',
#   'know?',
#   'just',
#   'as',
#   'know?',
#   'OK?',
#   'all',
#   'respect',
#   'need',
#   'know?',
#   'what',
#   'be',
#   'so,',
#   'know?',
#   'know',
#   'guys',
#   'gonna',
#   'know?\nAnother',
#   'gonna',
#   'just',
#   'want',
#   'know',
#   'know?',
#   'remember',
#   'were',
#   'just',
#   'could',
#   'throw',
#   'scratch',
#   'can',
#   'urgently',
#   'gotta',
#   'need',
#   'do',
#   'when',
#   'when',
#   'to',
#   'know?',
#   'that–',
#   'know',
#   'push,',
#   'push,',
#   'push,',
#   'think',
#   'wash',
#   'water',
#   'makin’',
#   'about',
#   'get',
#   'know?',
#   'know,',
#   'see',
#   'know?',
#   'know,',
#   'think'],
#  'for': ['coming.',
#   'coming.',
#   'me.',
#   'me.',
#   'me',
#   'my',
#   'fashion',
#   'warmth?',
#   'marriage,',
#   'them.',
#   'the',
#   'a',
#   'the',
#   'four',
#   'five',
#   'five',
#   'the',
#   'us,',
#   'Fresh',
#   'me',
#   'them.',
#   'his',
#   'the',
#   'once.',
#   'the',
#   'all',
#   'the',
#   'me',
#   'me,',
#   'me',
#   'a',
#   'granted',
#   'a',
#   'a',
#   'me.',
#   'a',
#   '30',
#   'coming',
#   'the',
#   'playing',
#   'being'],
#  'coming.': ['Hello!', 'Um…', 'You'],
#  'Hello.': ['We'],
#  'We': ['are',
#   'were',
#   'were',
#   'had',
#   'need',
#   'both',
#   'like',
#   'like',
#   'do',
#   'do',
#   'do',
#   'eat',
#   'got',
#   'had',
#   'could',
#   'don’t',
#   'could',
#   'all',
#   'don’t'],
#  'are': ['gonna',
#   'shocked',
#   'very',
#   'the',
#   'the',
#   'both',
#   'big',
#   'white',
#   'always',
#   'free',
#   'you',
#   'C.E.O.s,',
#   'never',
#   'a',
#   'you',
#   'you',
#   'like',
#   'your',
#   'droppin’.',
#   'in'],
#  'gonna': ['have',
#   'turn',
#   'die…',
#   'overtake',
#   'have',
#   'trap',
#   'propose…',
#   'stick',
#   'recognize',
#   'see',
#   'be',
#   'have',
#   'live.',
#   'tell',
#   'happen',
#   'have',
#   'become–',
#   'disappear,',
#   'become',
#   'have',
#   'before',
#   'make',
#   'be.',
#   'recycle…',
#   'burn',
#   'be.',
#   'poop',
#   'be'],
#  'have': ['to',
#   'to',
#   'a',
#   'insomnia',
#   'to',
#   'their',
#   'HPV',
#   'it',
#   'HPV',
#   'HPV,',
#   'one',
#   'the',
#   'the',
#   'a',
#   'a',
#   'to',
#   'a',
#   'a',
#   'these',
#   'done',
#   'been',
#   'any',
#   'so',
#   'to',
#   'your',
#   'to',
#   'to,',
#   'executive',
#   'some',
#   'a',
#   'a',
#   'a',
#   'had',
#   'children',
#   'any',
#   'a',
#   'to',
#   'a',
#   'sex,',
#   'to',
#   'had',
#   'to',
#   'the'],
#  'get': ['this',
#   'it.',
#   'it.',
#   'rid',
#   'it,',
#   'to',
#   'to',
#   'to',
#   'the',
#   'very',
#   'very',
#   'to',
#   'to',
#   'my',
#   'sicker,',
#   'sicker,',
#   'really,',
#   'a',
#   'a',
#   'all',
#   'us',
#   'to',
#   'pregnant.',
#   'pregnant,',
#   'up',
#   'into',
#   'older.',
#   'as',
#   'a',
#   'pregnant.',
#   'pregnant',
#   'that…',
#   'my',
#   'pregnant,',
#   'huge',
#   'dark',
#   'big–',
#   'big,',
#   'all',
#   'pregnant.'],
#  'this': ['shit',
#   'year.',
#   'doctor,',
#   'shit',
#   'shit',
#   'calculator',
#   'Judy',
#   'shit',
#   'past',
#   'past',
#   'wedding',
#   'dude',
#   'guy',
#   'restaurant',
#   'restaurant',
#   'hippy-dippy',
#   'sneaking',
#   'wacky',
#   'dude,',
#   'dude,',
#   'huge',
#   'shit?',
#   'conversation.',
#   'is',
#   'fucking',
#   'relatable',
#   'left',
#   'red',
#   'huge',
#   'aggressive',
#   'shit.”',
#   'shit',
#   'far',
#   'crazy',
#   'shit',
#   'dream'],
#  'shit': ['over',
#   'and',
#   'around?',
#   'around?',
#   'up',
#   'is',
#   'on',
#   'like',
#   'we',
#   'outta',
#   'in',
#   'in',
#   'in',
#   'was',
#   'together',
#   'together.”',
#   'turns',
#   'you',
#   'out',
#   'that',
#   'over',
#   'at',
#   'on',
#   'around',
#   'anymore.',
#   'that'],
#  'over': ['with,', 'again.', 'again.', 'by', 'his'],
#  'with,': ['’cause'],
#  '’cause': ['I',
#   'it',
#   'it',
#   'my',
#   'you’re',
#   'when',
#   'her',
#   'it’s',
#   'you',
#   'I'],
#  'I': ['have',
#   'turned',
#   'appreciate',
#   'can',
#   'see',
#   'don’t',
#   'have',
#   'have',
#   'have',
#   'can',
#   'turn',
#   'am,',
#   'turn',
#   'have',
#   'was',
#   'was',
#   'was',
#   'do',
#   'grew',
#   'also',
#   'gave',
#   'dated',
#   'first',
#   'saw',
#   'was',
#   'learned',
#   'was',
#   'trapped',
#   'did',
#   'knew',
#   'was',
#   'thought',
#   'was',
#   'saw',
#   'was',
#   'knew,',
#   'was',
#   'dropped',
#   'was',
#   'don’t',
#   'get',
#   'mean,',
#   'just',
#   'could',
#   'think',
#   'was',
#   'don’t',
#   'go',
#   'have',
#   'read',
#   'was',
#   'pee,',
#   'need',
#   'grew',
#   'are',
#   'had',
#   'just',
#   'had',
#   'just',
#   'wanted.',
#   'sent',
#   'told',
#   'bought',
#   'had',
#   'was',
#   'was',
#   'was',
#   'need',
#   'was.',
#   'did',
#   'don’t',
#   'don’t.',
#   'straight',
#   'don’t',
#   'do',
#   'don’t',
#   'don’t',
#   'wanna',
#   'want',
#   'think',
#   'guess',
#   'hear',
#   'wanna',
#   'love',
#   'love',
#   'still',
#   'gotta',
#   'literally',
#   'had',
#   'hear',
#   'lose',
#   'heard',
#   'was',
#   'know',
#   'heard',
#   'wanna',
#   'was',
#   'should',
#   'trapped',
#   'choose',
#   'chose',
#   'said,',
#   'really',
#   'don’t',
#   'got',
#   'got',
#   'think',
#   'started',
#   'was',
#   'went',
#   'don’t',
#   'was',
#   'finally',
#   'just',
#   'got',
#   'was,',
#   'got',
#   'just',
#   'don’t–',
#   'don’t!',
#   'don’t!',
#   'like',
#   'respect',
#   'know',
#   'don’t',
#   'also',
#   'just',
#   'can’t',
#   'can',
#   'told',
#   'want',
#   'wanna',
#   'can',
#   'want',
#   'want?',
#   'wanna',
#   'have',
#   'don’t',
#   'am',
#   'dare',
#   'just',
#   'identify.”',
#   'don’t',
#   'was',
#   'won,',
#   'was',
#   'really',
#   'changed',
#   'get',
#   'need',
#   'don’t',
#   'need',
#   'get',
#   'need',
#   'get',
#   'say',
#   'mean',
#   'also',
#   'know,',
#   'slime',
#   'don’t',
#   'did',
#   'was',
#   'ate',
#   'found',
#   'had',
#   'would',
#   'had',
#   'had',
#   'want',
#   'wanna',
#   'smell',
#   'smell',
#   'discretely',
#   'were',
#   'would',
#   'would',
#   'need',
#   'want',
#   'was',
#   'would',
#   'would',
#   'know',
#   'could',
#   'would',
#   'would',
#   'learned',
#   'would',
#   'don’t',
#   'had',
#   'can’t',
#   'wish',
#   'told',
#   'told',
#   'had',
#   'found',
#   'see',
#   'was',
#   'don’t',
#   'was',
#   'lost.',
#   'sat',
#   'sat',
#   'was',
#   'used',
#   'wanted',
#   'love',
#   'finally',
#   'always',
#   'was',
#   'look',
#   'can’t',
#   'can',
#   'am',
#   'didn’t',
#   'can',
#   'can’t',
#   'get',
#   'do',
#   'berate',
#   'really',
#   'have',
#   'gotta',
#   'didn’t',
#   'didn’t',
#   'look',
#   'will',
#   'do',
#   'was',
#   'was',
#   'looked',
#   'met',
#   'had',
#   'meet',
#   'discovered',
#   'don’t'],
#  'pee': ['in,', 'on'],
#  'in,': ['like,', 'OK?'],
#  'like,': ['ten',
#   '“You',
#   '“But…',
#   '“Oh,',
#   '“Oh,',
#   '“All',
#   'we',
#   '“Hey,',
#   '“Wassup?”',
#   '“Hey,',
#   '“Where?”',
#   '“At',
#   '“Oh,',
#   'you',
#   '“I',
#   '“Hold',
#   '“I',
#   '“It’s',
#   '“It’s',
#   'private',
#   '“Oh,',
#   '“I’m',
#   '“Shut',
#   '“Oh,',
#   'very',
#   '“We’re',
#   '“We',
#   '“But,',
#   '“Look',
#   '“That',
#   '“Oh,',
#   '“You',
#   '“Hey,',
#   '“Why',
#   '“Uh,',
#   '“Oh,',
#   '“Oh,',
#   '“Yes,',
#   'become',
#   'a',
#   '“Guys,',
#   '“That’s',
#   '“Ali,',
#   '“Yeah,',
#   '“Why',
#   '“Yeah,',
#   '“Yeah!',
#   '“Oh,',
#   '“I’m',
#   '“Oh,',
#   'only',
#   '“We’re',
#   '‘Release',
#   'we',
#   '“OK,',
#   '“Hey,',
#   '“Oh,',
#   '“Uh,',
#   '“No!”',
#   '“Yes!”',
#   '“You',
#   '“Yeah,',
#   'that',
#   'this',
#   'I',
#   'a',
#   'a',
#   'really',
#   '“Why',
#   'way'],
#  'ten': ['minutes.', 'gallons'],
#  'minutes.': ['But'],
#  'But': ['thank',
#   'my',
#   'I',
#   'he',
#   'sometimes,',
#   'don’t',
#   'I',
#   'he’s',
#   'mostly',
#   'I’m',
#   'it’s'],
#  'thank': ['you,'],
#  'you,': ['everybody,', 'five', 'but', 'right?”', 'I', '’cause', 'boom,'],
#  'everybody,': ['so'],
#  'so': ['much',
#   'emotional.',
#   'emotional',
#   'much',
#   'vulnerable',
#   'smooth,',
#   'that',
#   'good.',
#   'many',
#   'that',
#   'that',
#   'in',
#   'that',
#   'do',
#   'annoying',
#   'that',
#   'lonely.',
#   'juicy.',
#   'hot.',
#   'tired',
#   'dark',
#   'they',
#   'bad',
#   'bad',
#   'resentful',
#   'little',
#   'little',
#   'supportive.”',
#   'that',
#   'that'],
#  'much': ['for', 'better', 'chemistry.', 'shittier', 'Netflix', 'resentment,'],
#  'Um…': ['It’s'],
#  'It’s': ['a',
#   'been',
#   'OK.',
#   'coming.',
#   'really',
#   'what',
#   'like',
#   'so',
#   'all',
#   'different.',
#   'a',
#   'a',
#   'basically',
#   'like',
#   'because',
#   'very',
#   'so',
#   'a',
#   'lonely.',
#   'very',
#   'when',
#   'super',
#   'whatevs,',
#   'not'],
#  'a': ['very',
#   'very',
#   'shit',
#   'six-pack,',
#   'Ambien',
#   'Meditation',
#   'fucking',
#   'ghost',
#   'self-help',
#   'horrible',
#   'hoarding',
#   'hoarding',
#   'third',
#   'dictator’s',
#   'shovel',
#   'climax',
#   'Texas',
#   'procrastinator',
#   'lot',
#   'man',
#   'lot',
#   'grown-ass',
#   'mattress',
#   'kitchen.',
#   'very',
#   'catch.',
#   'secret',
#   'public',
#   'hipster?',
#   'homeless',
#   'lot',
#   'lot',
#   'major',
#   'Yoko',
#   'white',
#   'white',
#   'Wes',
#   'lot',
#   'white',
#   'white',
#   'dolphin.',
#   'slip',
#   'Jewish',
#   'huge',
#   'number',
#   'supply',
#   'grandma',
#   'weekend.',
#   'shitty',
#   'new',
#   'man',
#   'Pinterest',
#   'Saturday.',
#   'completely',
#   'lot',
#   'genius.”',
#   'housewife,',
#   'great',
#   'lot.',
#   'great',
#   'office',
#   'office',
#   'office.',
#   'day,',
#   'sad-ass',
#   'MacGyver',
#   'slow',
#   'lot',
#   'part',
#   'circle',
#   'lot',
#   'disgusting',
#   'pervert.',
#   'gross',
#   'very',
#   'young',
#   'idiot,',
#   'result,',
#   'little',
#   'second',
#   'conqueror.',
#   'little–',
#   'little',
#   'little',
#   'lot',
#   'lot',
#   'magical',
#   'big',
#   'ban',
#   'very',
#   'little',
#   'housewife,',
#   'certain',
#   'couple',
#   'dude',
#   'stroll',
#   'sidewalk,',
#   'quarter,',
#   'princess.',
#   'Vietnam',
#   'half',
#   'female',
#   'baby,',
#   'week',
#   'little',
#   'sudden.',
#   'frozen',
#   'lot',
#   'lot',
#   'kid.',
#   'kid?',
#   'lot',
#   'kid,',
#   'kid?',
#   'Asian',
#   'billion.',
#   'turtle',
#   'right',
#   'U-turn!”',
#   'O-turn!”',
#   'car',
#   'mess.',
#   'full',
#   'century',
#   'living.',
#   'fuck.',
#   'free',
#   'contest',
#   'kid',
#   'bubble',
#   'little',
#   'lot',
#   'smoker’s',
#   'side',
#   'sandwich.',
#   'way',
#   'doctor.',
#   'kid,',
#   'lot',
#   'lot',
#   'while,',
#   'bunch',
#   'dictatorship,',
#   'hand',
#   'man',
#   'zombie,',
#   'half',
#   'miscarriage,',
#   'lot',
#   'miscarriage.',
#   'third',
#   'pair',
#   'reason.',
#   'heartbeat.”',
#   'miscarriage.',
#   'month',
#   'bike',
#   'doula.',
#   'doula',
#   'white',
#   'soft',
#   'baby',
#   'child',
#   'marriage,',
#   'eyeball,',
#   'foot?',
#   'great',
#   'shitty',
#   'bad',
#   'daily',
#   'daily',
#   'bullseye.',
#   'Minion.',
#   'year,',
#   'nude',
#   'half',
#   'bunch',
#   'half',
#   'good'],
#  'very': ['exciting',
#   'exciting',
#   'unusual',
#   'confusing…',
#   'picturesque',
#   'underrated.',
#   'well',
#   'surprised',
#   'soft,',
#   'nurturing',
#   'domestic.',
#   'upset',
#   'judgmental',
#   'distracting',
#   'young',
#   'sexually',
#   'roundabout',
#   'rare',
#   'demoralizing,',
#   'clinical.',
#   'universal',
#   'grateful',
#   'common.',
#   'early.',
#   'much.',
#   'scared'],
#  'exciting': ['day', 'year'],
#  'day': ['for',
#   'and',
#   'was',
#   'jobs,',
#   'long.',
#   'looks',
#   'since.',
#   'long.',
#   'on'],
#  'me.': ['It’s',
#   'I',
#   'And',
#   '‘Cause',
#   'When–',
#   'OK?”',
#   'You',
#   'Because',
#   'Like,',
#   'That’s',
#   'And',
#   '“Oh,',
#   'I',
#   'Oh,',
#   'How'],
#  'been': ['a',
#   'dating',
#   'pressuring',
#   'together',
#   'reading',
#   'to',
#   'run',
#   'eating',
#   'trying',
#   'Ali'],
#  'year': ['for', 'I'],
#  'turned': ['33'],
#  '33': ['this', 'and…'],
#  'year.': ['Yes!', 'Uh,'],
#  'Yes!': ['Thank'],
#  'five': ['people.', 'years,', 'years,'],
#  'people.': ['I', 'It’s…', 'Like,', 'I', 'That’s'],
#  'appreciate': ['that.'],
#  'that.': ['Uh,', 'Uh,', 'They', 'Don’t', 'I’m', 'They’re', 'I'],
#  'Uh,': ['I', 'this', 'we'],
#  'can': ['tell',
#   'also',
#   'I',
#   'I',
#   'never',
#   'you',
#   'be',
#   'tell,',
#   'tell',
#   'never',
#   'listen',
#   'do',
#   'talk,',
#   'comfortably',
#   'tell,',
#   'just',
#   'think',
#   'I',
#   'I',
#   'I',
#   'already',
#   'really',
#   'you',
#   'already',
#   'see,',
#   'find'],
#  'tell': ['that',
#   'that',
#   'by',
#   'you',
#   'them',
#   'me',
#   'you',
#   'you',
#   'you',
#   'because',
#   'you'],
#  'that': ['I’m',
#   'huge',
#   'says',
#   'they',
#   'lives',
#   'I',
#   'I’m',
#   'if',
#   'you',
#   'retainer',
#   'with',
#   'calculator',
#   'bamboozled',
#   'I’m',
#   'he',
#   'your',
#   'beard',
#   'shit',
#   'and',
#   'privilege',
#   'entitlement…',
#   'for',
#   'you',
#   'bread',
#   'tastes',
#   'lesbian',
#   'seems',
#   'he',
#   'you’re',
#   'I',
#   'I',
#   'so',
#   'he’d',
#   'book',
#   'book',
#   'got',
#   'ever',
#   'we’ll',
#   'fucking',
#   'housewife,',
#   'horrible',
#   'one-ply',
#   'office',
#   'they',
#   'your',
#   'the',
#   'no',
#   'shit',
#   'you',
#   'I',
#   'if',
#   'he’s',
#   'and',
#   'you',
#   'if',
#   'then,',
#   'they’re',
#   'fear.',
#   'fear',
#   'he',
#   'we',
#   'I’m',
#   'I',
#   'woman',
#   'now,',
#   'Whole',
#   'was',
#   'was',
#   'everybody',
#   'it’s',
#   'came',
#   'she’s',
#   '’cause',
#   'to',
#   'you',
#   'snail-trail',
#   'my',
#   'were',
#   'it',
#   'it’s',
#   'tell',
#   'means,',
#   'they',
#   'they',
#   'day',
#   'says,',
#   'stupid-ass',
#   'I',
#   'Harvard',
#   'I',
#   'shit',
#   'is?',
#   'you’re',
#   'you–',
#   'that',
#   'happens',
#   'he',
#   'he’s',
#   'goes',
#   'they',
#   'the',
#   'the',
#   'I’m',
#   'my'],
#  'I’m': ['getting',
#   'straight',
#   'jealous,',
#   'gonna',
#   'getting',
#   'not',
#   'interested',
#   'a',
#   'not',
#   'hoping',
#   'hoping',
#   'gonna',
#   'not',
#   'the',
#   'gonna',
#   'absorbing',
#   'half-Chinese',
#   'half-Chinese',
#   'a',
#   'very',
#   'like,',
#   "done.'”",
#   'done.',
#   'not',
#   'a–',
#   'a',
#   'a',
#   'a',
#   'scared',
#   'a',
#   'going',
#   'gonna',
#   'gonna',
#   'tired',
#   'the',
#   'the',
#   'just',
#   'talking',
#   'talking',
#   'striving',
#   'a',
#   'a',
#   'guaranteed,',
#   'still',
#   'just',
#   'older,',
#   'not',
#   'only',
#   'only',
#   'gonna',
#   '33,',
#   'very',
#   '33.',
#   'from,',
#   'scared',
#   'very,',
#   'going',
#   'all',
#   'busy',
#   'the',
#   'not',
#   'a',
#   'fucked.',
#   'not',
#   'seven',
#   'performing'],
#  'getting': ['older,', 'older,', 'busy', 'massages'],
#  'older,': ['because,', 'because', 'when'],
#  'because,': ['now,', 'usually,', 'last'],
#  'now,': ['when', 'because', 'instead', 'and', 'if'],
#  'when': ['I',
#   'they',
#   'a',
#   'you’re',
#   'she',
#   'we',
#   'you',
#   'you',
#   'I',
#   'you’re',
#   'a',
#   'our',
#   'you',
#   'we',
#   'I',
#   'I',
#   'I',
#   'I',
#   'you',
#   'he',
#   'I',
#   'that',
#   'you',
#   'you’re',
#   'they',
#   'I',
#   'I’m',
#   'I',
#   'I',
#   'my',
#   'you',
#   'trying',
#   'I',
#   'everything',
#   'I',
#   'the',
#   'it’s',
#   'it',
#   'they',
#   'I',
#   'he',
#   'a',
#   'they',
#   'they',
#   'you’re',
#   'they',
#   'I',
#   'they’re',
#   'you’re',
#   'you',
#   'he',
#   'you',
#   'I',
#   'it',
#   'it’s'],
#  'see': ['an',
#   'ten',
#   'on',
#   'that',
#   'the',
#   'a',
#   'a',
#   'how',
#   'that',
#   'who’s',
#   'a',
#   'the',
#   'the',
#   'two',
#   'is',
#   'Beyoncé.',
#   'how',
#   'how',
#   'if',
#   'me'],
#  'an': ['18-year-old', 'ATM', 'impression', 'investment'],
#  '18-year-old': ['girl,', 'girls,'],
#  'girl,': ['my', 'because'],
#  'my': ['automatic',
#   'body',
#   'Kindle',
#   'home',
#   'optimum',
#   'other',
#   'mom',
#   'life.',
#   'generation.',
#   'time.',
#   'mom',
#   'optimum',
#   'husband,',
#   'league,',
#   'God,',
#   'God,',
#   'part.',
#   'generation.',
#   'Volvo.',
#   'pussy.',
#   'God.',
#   'God.',
#   'bed',
#   'husband',
#   'God!',
#   'Pinterest',
#   'best',
#   'wedding',
#   'husband,',
#   'personality',
#   'heart.',
#   'financial',
#   'friends,',
#   'co-workers.',
#   'toilet',
#   'fingers',
#   'co-workers',
#   'co-workers',
#   'shit',
#   'husband',
#   'life?',
#   'destiny.',
#   'last',
#   'mom,',
#   'dad,',
#   'grandma.”',
#   '20s,',
#   'God!',
#   'God!',
#   'husband',
#   'Asian-American',
#   'female',
#   'friends',
#   'husband',
#   'mind,',
#   'mind',
#   'God,',
#   'face',
#   'husband',
#   'destiny,',
#   'body',
#   'God,',
#   'fault.',
#   '20s,',
#   'uterus',
#   'progesterone',
#   'writing',
#   'co-workers,',
#   'underwear,',
#   'fingers',
#   'fingers',
#   'own',
#   'fingers?',
#   'fingers?',
#   'fingers?”',
#   'husband',
#   'God,',
#   'husband',
#   'face',
#   'God.',
#   'mom–',
#   'six-week',
#   'God,',
#   'husband',
#   'miscarriage',
#   'shit',
#   'husband.',
#   'husband',
#   'doctor’s',
#   'God.',
#   'blood',
#   'husband',
#   'pussy’s',
#   'pussy’s',
#   'body’s',
#   'husband,',
#   'league,',
#   'God,',
#   'dreams',
#   'beautiful,',
#   'hard-earned',
#   'ass.'],
#  'automatic': ['thought…'],
#  'thought…': ['is'],
#  'is': ['“Fuck',
#   'a',
#   'turning',
#   'all',
#   'the',
#   'from',
#   'that?”',
#   'a',
#   'a',
#   'Asian.',
#   'turning',
#   'that',
#   'built',
#   'all',
#   'the',
#   'too',
#   'like,',
#   'always,',
#   'called',
#   'the',
#   'a',
#   'to',
#   'that…',
#   'doo',
#   'unfortunately',
#   'what',
#   'a',
#   'a',
#   'at',
#   'the',
#   'a',
#   '80,',
#   'so',
#   'not',
#   'not',
#   'not',
#   'most',
#   'fine',
#   'very',
#   'about',
#   'very',
#   'very',
#   'a',
#   'mysterious!”',
#   'so',
#   'it'],
#  '“Fuck': ['you.”', 'you.'],
#  'you.”': ['“Fuck', 'My'],
#  'you.': ['I', 'A', 'Don’t', 'There’s–', 'Ghostbusters!”', 'You'],
#  'don’t': ['even',
#   'have',
#   'know',
#   'have',
#   'have',
#   'have',
#   'know',
#   'even',
#   'know',
#   'know',
#   'gotta',
#   'know',
#   'go',
#   'got',
#   'wanna',
#   'wanna',
#   'feed',
#   'wanna',
#   'wanna',
#   'know',
#   'think',
#   'gotta',
#   'gotta',
#   'gotta…',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'gotta',
#   'wanna',
#   'wanna',
#   'worry,',
#   'cheat',
#   'wanna',
#   'wanna',
#   'want',
#   'know',
#   'get',
#   'know',
#   'you',
#   'crack.”',
#   'die.',
#   'die.',
#   'know',
#   'give',
#   'know',
#   'wanna',
#   'see',
#   'tell',
#   'work,'],
#  'even': ['know', 'know…', 'accidentally', 'effective.', 'have', 'come'],
#  'know': ['you,',
#   'what',
#   'that',
#   'when',
#   'what',
#   'when',
#   'what’s',
#   'why',
#   'the',
#   'anything',
#   'what',
#   'that',
#   'how',
#   'how',
#   'you',
#   'that',
#   'I',
#   'you',
#   'you’ve',
#   'what',
#   'if',
#   'what’s',
#   'the',
#   'why',
#   'what’s',
#   'what',
#   'what',
#   'plenty',
#   'what',
#   'what',
#   'that',
#   'that.',
#   'that'],
#  'but': ['fuck', 'I', 'it’s', 'I', 'I’m', 'my'],
#  'fuck': ['you!”', 'they', 'up!', 'down.', 'one', 'him', 'up.”', 'I'],
#  'you!”': ['‘Cause'],
#  '‘Cause': ['I’m', 'he', 'I', 'it’s', 'if', 'she', 'I'],
#  'straight': ['up', 'up', 'up'],
#  'up': ['jealous.',
#   'your',
#   'when',
#   'a',
#   'on',
#   'with',
#   'in',
#   'afterwards.',
#   'on',
#   'like',
#   'going',
#   'for',
#   'on',
#   'and',
#   'don’t',
#   'about',
#   'to',
#   'a',
#   'to',
#   'with',
#   'there',
#   'on',
#   'the',
#   'myself',
#   'from',
#   'your',
#   'soldier'],
#  'jealous.': ['I’m'],
#  'jealous,': ['first'],
#  'first': ['and', 'met', 'thing', 'dates,', 'and', 'lady', 'WebMD.', 'home'],
#  'foremost,': ['of', 'by'],
#  'of': ['their',
#   'potential',
#   'regret',
#   'them.',
#   'men',
#   'two',
#   'HPV.',
#   'Wolverine,',
#   'Grey,',
#   'Tidying',
#   'success.',
#   'all',
#   'my',
#   'shit.',
#   'my',
#   'a',
#   'you',
#   'my',
#   'success.”',
#   'losers.',
#   'losers.',
#   'skaters.',
#   'my',
#   'my',
#   'people',
#   'opinions,',
#   'cool',
#   'that',
#   'that',
#   'your',
#   'our',
#   'our',
#   'Los',
#   'all,',
#   'bleach,',
#   'your',
#   'this',
#   'Asian',
#   'us',
#   'the',
#   'my',
#   'Facebook,',
#   'women',
#   'options',
#   'my',
#   'day',
#   'the',
#   'the',
#   'their',
#   'credence.',
#   'my',
#   'privileged',
#   'this',
#   'my',
#   'early',
#   'myself',
#   'women',
#   'the',
#   'the',
#   'crazy',
#   'the',
#   'is',
#   'your',
#   'mine',
#   'resistance',
#   '“No!',
#   'the',
#   'control,',
#   'control',
#   'being',
#   'her,',
#   'saying,',
#   'saying:',
#   'income',
#   'one.',
#   'them.',
#   'shit.',
#   'a',
#   'my',
#   'my',
#   'your',
#   'nowhere.',
#   'their',
#   'her',
#   'those',
#   'longevity.',
#   'change.',
#   'mother',
#   'science',
#   'that…',
#   'my',
#   'the',
#   'people',
#   'fuckin’?”',
#   'the',
#   'that,',
#   'angry',
#   'the',
#   'the',
#   'your',
#   'their',
#   'their',
#   'him…',
#   'this',
#   'that',
#   'me.',
#   'women',
#   'women',
#   'shoes.',
#   'poppy',
#   'me',
#   'Craigslist.',
#   'childbirth.',
#   'women',
#   'the',
#   'your',
#   'life,',
#   'how',
#   'my',
#   'the',
#   'survival,',
#   'another',
#   'those',
#   'body',
#   'losers.',
#   'my',
#   'white-collar'],
#  'their': ['metabolism.',
#   'feet',
#   'whole',
#   'house.',
#   'communist',
#   'shit,',
#   'doo',
#   'hallways',
#   'iPad',
#   'eyebrows,',
#   'prostate.',
#   'fame',
#   'existence.',
#   'big-ass',
#   'Darth',
#   'arch-nemesis,',
#   'eyes',
#   'eyes.',
#   'eyes',
#   'head',
#   'eyelids.',
#   'face…',
#   '20s',
#   'husbands'],
#  'metabolism.': ['Because'],
#  'Because': ['18-year-old', 'according', 'I’m', 'I’m', 'we’re'],
#  'girls,': ['they'],
#  'they': ['could',
#   'take',
#   'put',
#   'go',
#   'just',
#   'have',
#   'were',
#   'like',
#   'teach',
#   'mean.',
#   'don’t',
#   'purposely',
#   'don’t',
#   'want.',
#   'want.\nYou',
#   'say',
#   'wax',
#   'do',
#   'like',
#   'just',
#   'do',
#   'generally',
#   'have',
#   'become',
#   'were',
#   'were',
#   'were',
#   'don’t',
#   'can',
#   'come',
#   'just',
#   'need',
#   'saw',
#   'get',
#   'look',
#   'just',
#   'hear',
#   'wouldn’t',
#   'go',
#   'get',
#   'get',
#   'get',
#   'get'],
#  'could': ['just',
#   'graph.',
#   'just',
#   'just',
#   'have',
#   'do',
#   'do',
#   'ask',
#   'just',
#   'just',
#   'always'],
#  'just': ['eat',
#   'radiating',
#   'go',
#   'cluttering',
#   'go',
#   'fucked',
#   'feel',
#   'right',
#   'crush',
#   'kill',
#   'like',
#   'smell',
#   'had',
#   'had',
#   'gonna',
#   'nag',
#   'stay',
#   'walking',
#   'dehydrates',
#   'blow',
#   'fulfilling',
#   'put',
#   'felt',
#   'wanted',
#   'see',
#   'become',
#   'not',
#   'wanna',
#   'want',
#   'wanna',
#   'wanna',
#   'waiting',
#   'keep',
#   'had',
#   'swells',
#   'gonna',
#   'travel',
#   'do',
#   'kidding.',
#   'gonna',
#   'sopping',
#   'took',
#   'reach',
#   'blow',
#   'scratch',
#   'vacuum,',
#   'come',
#   'give',
#   'got',
#   'twerk,',
#   'drain',
#   'shit',
#   'when'],
#  'eat': ['like',
#   'gluten-free,',
#   'all',
#   'that',
#   'it,',
#   'snacks',
#   'a',
#   'bananas.”'],
#  'like': ['shit,',
#   'to',
#   'Fifty',
#   'the',
#   '$200.',
#   'this',
#   'the',
#   'to',
#   'you’re',
#   'voting',
#   'that',
#   'I’m',
#   'making',
#   'a',
#   'loofah',
#   'responsibility.',
#   'host',
#   'Filipino',
#   'to',
#   'to',
#   'that.',
#   'free-range',
#   'we',
#   'you’re',
#   'wiping',
#   'it’s',
#   'you’re',
#   'I',
#   'I’m',
#   'a',
#   'it,',
#   'that',
#   'he’s',
#   'you’re',
#   'to',
#   'a',
#   'the',
#   'skittles.',
#   'a',
#   'everything',
#   'a',
#   'they',
#   'losing',
#   'fingers.',
#   'Whoppers',
#   'a',
#   'when'],
#  'shit,': ['and', 'too.'],
#  'then': ['they',
#   'after',
#   'also,',
#   'Asian',
#   'if',
#   'afterwards,',
#   'it',
#   'I',
#   'you',
#   'you',
#   'your',
#   'if',
#   'I',
#   'I',
#   'resist',
#   'he',
#   'I',
#   'she',
#   'we',
#   'we'],
#  'take': ['a', 'a', 'these', 'a', 'these', 'its'],
#  'six-pack,': ['right?'],
#  'right?': ['They', 'That’s', 'So,', 'You'],
#  'They': ['got',
#   'don’t',
#   'don’t',
#   'have',
#   'don’t',
#   'just',
#   'introduce',
#   'got',
#   'just',
#   'get',
#   'ruined',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'try',
#   'don’t',
#   'don’t',
#   'don’t',
#   'can',
#   'can',
#   'would',
#   'get',
#   'just',
#   'got',
#   'do',
#   'do',
#   'wear',
#   'just',
#   'make',
#   'watch',
#   'were',
#   'tried'],
#  'got': ['that-that',
#   'so',
#   'married.',
#   'no',
#   'a',
#   'me',
#   'engaged',
#   'women',
#   'married',
#   'married.',
#   'a',
#   'married',
#   'a',
#   'no',
#   'bit',
#   'him',
#   'married,',
#   'pregnant,'],
#  'that-that': ['beautiful'],
#  'beautiful': ['inner'],
#  'inner': ['thigh', 'peace', 'evil,'],
#  'thigh': ['clearance'],
#  'clearance': ['where'],
#  'where': ['they', 'my', 'I', 'the', 'the', 'I'],
#  'put': ['their', 'it', 'it', 'it'],
#  'feet': ['together'],
#  'together': ['and', 'now', 'to', 'when'],
#  'there’s': ['that', 'multiple'],
#  'huge': ['gap', 'unspoken', 'sit-down', 'bear', 'and'],
#  'gap': ['here'],
#  'here': ['with', 'is'],
#  'with': ['the',
#   'where',
#   'your',
#   'all',
#   'these',
#   'a',
#   'a',
#   'a',
#   'somebody',
#   'a',
#   'glaucoma',
#   'our',
#   'this',
#   'my',
#   'him.',
#   'me',
#   'their',
#   'the',
#   'which',
#   'me',
#   'the',
#   'eyelashes.',
#   'my',
#   'a',
#   'male',
#   'your',
#   'no',
#   'me,',
#   'it,',
#   'you',
#   'intention,',
#   'me.',
#   'your',
#   'my'],
#  'light': ['of', 'completely.”'],
#  'potential': ['just'],
#  'radiating': ['through.\nAnd'],
#  'through.\nAnd': ['then,'],
#  'then,': ['when',
#   'all',
#   'it',
#   'you',
#   'on',
#   'at',
#   'at',
#   'a',
#   'when',
#   'because',
#   'I',
#   'you',
#   'I'],
#  'go': ['to',
#   'to',
#   'to',
#   'and',
#   'and',
#   'of',
#   'to',
#   'home…',
#   'for',
#   'on',
#   'very',
#   'back',
#   'call',
#   'home',
#   'paintballing',
#   'bald…',
#   'to',
#   'time,”',
#   'through',
#   'to'],
#  'sleep,': ['they'],
#  'sleep.': ['Right?'],
#  'Right?': ['They'],
#  'insomnia': ['yet.'],
#  'yet.': ['They', 'They'],
#  'what': ['it’s',
#   'that',
#   'your',
#   'that',
#   'love',
#   'the',
#   'I',
#   'happens',
#   'he',
#   'to',
#   'I’m',
#   'else',
#   'everybody',
#   'kind',
#   'that',
#   'I',
#   'that',
#   'a'],
#  'it’s': ['like',
#   'undetectable',
#   'a',
#   'very,',
#   'hot',
#   'funny,',
#   'too',
#   'probably',
#   'been',
#   'very',
#   'because',
#   'OK,',
#   'like',
#   'the',
#   'sexist',
#   'a',
#   'what',
#   'a',
#   'all',
#   'too',
#   'Easter',
#   'like,',
#   'go',
#   'not',
#   'because',
#   'different.',
#   'straight',
#   'Neosporin.'],
#  'Ambien': ['or'],
#  'or': ['download',
#   'you’re',
#   'you',
#   'for',
#   'something.',
#   'whatever.',
#   'something…'],
#  'download': ['a'],
#  'Meditation': ['Oasis'],
#  'Oasis': ['podcast'],
#  'podcast': ['to'],
#  'calm': ['the'],
#  'chatter': ['of'],
#  'regret': ['and'],
#  'resentment': ['towards'],
#  'towards': ['your', 'my'],
#  'your': ['family',
#   'mind.',
#   '30s',
#   'wealth.',
#   'butt',
#   'mom.',
#   'body',
#   'head',
#   'own',
#   'body',
#   'daily',
#   'butt',
#   'butt',
#   'co-worker’s',
#   'shoes',
#   'butt',
#   'underwear',
#   'shit',
#   'children',
#   'understand',
#   'son',
#   'shame,',
#   'inner',
#   'secrets',
#   'man',
#   'thumb',
#   'husband',
#   'lives',
#   'pussy',
#   'hand',
#   'pants',
#   'fingers.',
#   'first',
#   '20s,',
#   '30s,',
#   'sperm',
#   'face',
#   'pussy',
#   'husband',
#   'leg,',
#   'life.',
#   'doctor’s',
#   'body'],
#  'family': ['just', 'would', 'funny'],
#  'cluttering': ['your'],
#  'mind.': ['They'],
#  'whole': ['lives', 'manipulation', 'new', 'thing.”'],
#  'lives': ['ahead', 'inside', 'with'],
#  'ahead': ['of'],
#  'them.': ['They', 'They’re', 'Nothing', 'Once', 'They'],
#  'HPV': ['yet.', 'yet,', 'is', 'will'],
#  'sleep': ['in'],
#  'in': ['peace',
#   'men.',
#   'women’s',
#   'the',
#   'books',
#   'The',
#   'handy',
#   'San',
#   'eight',
#   'a',
#   'San',
#   'broad',
#   'the',
#   'a',
#   'America',
#   'a',
#   'my',
#   'it.',
#   'the',
#   'and',
#   'men.',
#   '2012.',
#   'my',
#   'her',
#   'terms',
#   'a',
#   'a',
#   'their',
#   'doo',
#   'the',
#   'the',
#   'the',
#   'her',
#   'different',
#   'my',
#   'time!”',
#   'the',
#   'the',
#   'his',
#   'his',
#   'bed.',
#   'control',
#   'the',
#   'elementary',
#   'the',
#   'their–',
#   'a',
#   'between',
#   'my',
#   'front',
#   'the',
#   'your',
#   'your',
#   'such',
#   'the',
#   'Atlanta.',
#   'their',
#   'front',
#   'my',
#   'labor,',
#   'the',
#   'front',
#   'our',
#   'shape',
#   'a',
#   'debt.'],
#  'peace': ['at', 'and', 'sign'],
#  'at': ['night.',
#   'home',
#   'this',
#   'the',
#   'Golden',
#   'any',
#   'how,',
#   'all',
#   'the',
#   'home',
#   'that',
#   'that',
#   'a',
#   'work',
#   'the',
#   'a',
#   'a',
#   'a',
#   'life,',
#   'first.',
#   'home,',
#   'any',
#   'my',
#   'Fresh',
#   'some',
#   'my',
#   'work.',
#   'him.',
#   'his'],
#  'night.': ['Everybody', 'And'],
#  'Everybody': ['has', 'has', 'has'],
#  'has': ['HPV,',
#   'it.',
#   'it.',
#   'HPV.',
#   'hosted',
#   'even',
#   'made',
#   'to',
#   'a',
#   'had',
#   'to'],
#  'HPV,': ['OK?', 'because'],
#  'OK?': ['Everybody',
#   'I’m',
#   'That',
#   'So,',
#   'A',
#   'I',
#   'You',
#   'So,',
#   'Are',
#   'We',
#   'I',
#   'Old',
#   'Do',
#   'When',
#   'When',
#   'They',
#   'Are'],
#  'it.': ['It’s',
#   'If',
#   'You',
#   'It’s',
#   'You',
#   'Second',
#   'So,',
#   'Sheryl',
#   'I',
#   'When',
#   'Now',
#   'That’s'],
#  'OK.': ['Come', 'And'],
#  'Come': ['out'],
#  'out': ['already.',
#   'of',
#   'there',
#   'of',
#   'at',
#   'about',
#   'down',
#   'of',
#   'of',
#   'of',
#   'first.',
#   'that',
#   'of',
#   'like',
#   'of',
#   'of',
#   'when',
#   'at',
#   'about',
#   'yet',
#   'of',
#   'of'],
#  'already.': ['Everybody'],
#  'If': ['you', 'it', 'a', 'you’re', 'you', 'it’s'],
#  'it': ['yet,',
#   'might',
#   'all',
#   'when',
#   'was',
#   'on',
#   'can',
#   'on',
#   'don’t',
#   'was',
#   'on',
#   'on',
#   'as',
#   'so',
#   'for',
#   'a',
#   'backfired',
#   'echo',
#   'in',
#   'in',
#   'in',
#   'up.',
#   'up,',
#   'interesting.',
#   'in',
#   'before,',
#   'tonight.',
#   'might',
#   'up.',
#   'was',
#   'in',
#   'scared',
#   'used',
#   'for',
#   'was',
#   'made',
#   'gets',
#   'was',
#   'so',
#   'as',
#   'very',
#   'takes',
#   'also',
#   'easier.',
#   'was',
#   'different?”',
#   'up,',
#   'all',
#   'turns'],
#  'yet,': ['you', 'you’re'],
#  'You': ['go',
#   'don’t',
#   'wanna',
#   'homeless',
#   'go',
#   'feel',
#   'feel',
#   'know?\nBut',
#   'get',
#   'don’t',
#   'guys',
#   'mess',
#   'guys',
#   'can',
#   'gotta',
#   'guys',
#   'tell',
#   'ain’t',
#   'have',
#   'gotta',
#   'gotta',
#   'only',
#   'know',
#   'know?',
#   'know',
#   'know,',
#   'just',
#   'could',
#   'guys',
#   'pee',
#   'know',
#   'know',
#   'just',
#   'change',
#   'know,',
#   'owe'],
#  'you’re': ['a',
#   'in',
#   'busy',
#   'with',
#   'in',
#   'like,',
#   'too',
#   'like,',
#   'about',
#   'paranoid',
#   'like,',
#   'a',
#   'really',
#   'married,',
#   'gonna',
#   'fucking',
#   'the',
#   'supposed',
#   'eating',
#   'gonna',
#   'in',
#   '33,',
#   'having',
#   'gonna',
#   'in'],
#  'fucking': ['loser,', 'housewife.', 'different', 'baby.', 'baby,'],
#  'loser,': ['all'],
#  'all': ['right?',
#   'about.',
#   'of',
#   'your',
#   'came',
#   'required',
#   'this',
#   'his',
#   'of',
#   'of',
#   'the',
#   'up',
#   'fucked',
#   'red',
#   'that',
#   'of',
#   'over',
#   'with',
#   'riled',
#   'day',
#   'these',
#   'day,',
#   'over',
#   'day',
#   'the',
#   'sorts',
#   'of',
#   'your',
#   'he’s',
#   'squirmy',
#   'right?',
#   'the',
#   'the',
#   'my',
#   'these',
#   'of',
#   'know',
#   'the',
#   'day',
#   'you',
#   'good',
#   'of',
#   'the',
#   'backed',
#   'of',
#   'your',
#   'this',
#   'back',
#   'wet',
#   'wet',
#   'my',
#   'off.'],
#  'That’s': ['what',
#   'what',
#   'where',
#   'right,',
#   'how',
#   'how',
#   'right.',
#   'the',
#   'when',
#   'not',
#   'the',
#   'not',
#   'shit',
#   'right.',
#   'so',
#   'my',
#   'why',
#   'a',
#   'the',
#   'not'],
#  'says': ['about', 'to'],
#  'about': ['you.',
#   'the',
#   'him',
#   'a',
#   'Vietnamese',
#   'it',
#   'our',
#   'how',
#   'those',
#   'housewives',
#   'to',
#   'the',
#   'money.',
#   'anal.',
#   'is,',
#   'that',
#   'is,',
#   'to',
#   'to',
#   'it',
#   'giving',
#   'childbirth',
#   'all'],
#  'A': ['lot', 'lot', 'woman', 'lot', 'lot', 'whole', 'big', 'lot'],
#  'lot': ['of',
#   'this',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'more',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of'],
#  'men': ['don’t', 'are', 'are', 'as'],
#  'because': ['it’s',
#   'my',
#   'my',
#   'you',
#   'what?',
#   'before',
#   'I',
#   'being',
#   'he’s',
#   'he’s',
#   'you',
#   'I',
#   'you',
#   'I',
#   'the',
#   'he',
#   'you',
#   'we’re',
#   'of',
#   'according',
#   'boys',
#   'female',
#   'they',
#   'uh,',
#   'they’re',
#   'they’re',
#   'then',
#   'the',
#   'we’re',
#   'when',
#   'the',
#   'I',
#   'if',
#   'my–',
#   'he'],
#  'undetectable': ['in'],
#  'men.': ['It’s', 'We'],
#  'really': ['fucked',
#   'work,',
#   'meant',
#   'scared',
#   'am!”',
#   'take',
#   'am',
#   'hot,'],
#  'fucked': ['up.', 'a', 'up'],
#  'up.': ['HPV', 'A', 'You', 'She’s'],
#  'ghost': ['that'],
#  'inside': ['men’s', 'of'],
#  'men’s': ['bodies'],
#  'bodies': ['and'],
#  'says,': ['“Boo!”', '“Please,'],
#  '“Boo!”': ['in'],
#  'women’s': ['bodies.', 'intuition.'],
#  'bodies.': ['My'],
#  'My': ['doctor',
#   'husband',
#   'husband,',
#   'father-in-law',
#   'husband',
#   'Toyota',
#   'mom',
#   'nipples'],
#  'doctor': ['told', 'says', 'appointments.'],
#  'told': ['me', 'her', 'you', 'my', 'her'],
#  'me': ['that',
#   'that',
#   'to',
#   'something.',
#   'off?”',
#   'feel',
#   'to',
#   'feel',
#   'the',
#   'tell',
#   'about',
#   'with',
#   'when',
#   'anymore',
#   'and',
#   'to',
#   'and',
#   'this',
#   'on,',
#   'and',
#   'enough',
#   'discouraged',
#   'from',
#   'when',
#   'from',
#   'see',
#   'of',
#   'company',
#   'when',
#   'when',
#   'anymore.',
#   'extremely',
#   'in',
#   'while',
#   'to',
#   'a',
#   'out.',
#   'out',
#   'to',
#   'money,',
#   'in',
#   'for'],
#  'one': ['of', 'of', 'of', 'of', 'person', 'of', 'of', 'who'],
#  'two': ['strains', 'homeless', 'days', 'Latina', 'sacks,', 'weeks'],
#  'strains': ['of'],
#  'HPV.': ['Either', 'Very'],
#  'Either': ['I'],
#  'kind': ['that’s', 'where', 'of', 'of', 'of', 'of'],
#  'that’s': ['gonna',
#   'right,',
#   'not',
#   'like…',
#   'not',
#   'gonna',
#   'why',
#   'the',
#   'cool…',
#   'so',
#   'like',
#   'enough'],
#  'turn': ['into', 'this', 'this', 'into', 'signal', 'upside'],
#  'into': ['cervical',
#   'a',
#   'the',
#   'a',
#   'the',
#   'banana',
#   'the',
#   'the',
#   'the',
#   'a',
#   'pleasure.',
#   'a',
#   'my',
#   'your',
#   'a',
#   'the'],
#  'cervical': ['cancer…'],
#  'cancer…': ['…or'],
#  '…or': ['I'],
#  'body': ['will', 'is', 'hair', 'is', 'odor.', 'was', 'when', 'where,'],
#  'will': ['heal', 'also', 'also', 'you', 'always', 'be', 'have', 'commend'],
#  'heal': ['itself.', 'from'],
#  'itself.': ['Very'],
#  'Very': ['helpful,', 'lucky'],
#  'helpful,': ['this'],
#  'doctor,': ['right?'],
#  'So,': ['basically,',
#   'you',
#   'we’re',
#   'he',
#   'you',
#   'you’re',
#   'I',
#   'when',
#   'now,',
#   'I',
#   'I',
#   'my',
#   'then',
#   'then',
#   'I',
#   'you',
#   'as'],
#  'basically,': ['either'],
#  'either': ['I’m'],
#  'die…': ['or'],
#  'presence': ['of'],
#  'Wolverine,': ['bitches.'],
#  'bitches.': ['We’ll', 'I'],
#  'We’ll': ['find'],
#  'find': ['out.', 'a', 'ways', 'a', 'it'],
#  'out.': ['Um,', 'They', 'They', 'They'],
#  'Um,': ['I', 'and'],
#  'also': ['tell', 'disappear.', 'got', 'last', 'don’t', 'decided', 'takes'],
#  'Kindle': ['is'],
#  'turning': ['into', 'into'],
#  'self-help': ['library.'],
#  'library.': ['I’m'],
#  'not': ['interested',
#   'happy',
#   'trying',
#   'the',
#   'kissing',
#   'ask',
#   'authentic,',
#   'recognize',
#   'a',
#   'even',
#   'have',
#   'be',
#   'dieting',
#   'scared',
#   'as',
#   'the',
#   'again!”',
#   'Rush',
#   'trying',
#   'my',
#   'technically',
#   'as',
#   'OK.',
#   'fuckin’.',
#   'because',
#   'doing',
#   'there.',
#   'gonna',
#   'like',
#   'the'],
#  'interested': ['in', 'in'],
#  'books': ['like'],
#  'Fifty': ['Shades'],
#  'Shades': ['of'],
#  'Grey,': ['OK?'],
#  'The': ['Life-Changing',
#   'manual.',
#   'next',
#   'advantage',
#   'fancy',
#   'images',
#   'Boat,'],
#  'Life-Changing': ['Magic'],
#  'Magic': ['of'],
#  'Tidying': ['Up.'],
#  'Up.': ['Yes.'],
#  'Yes.': ['Yes,', 'Yes.', 'Yes.', 'I', 'Because'],
#  'Yes,': ['that’s'],
#  'right,': ['how', 'Ali,', 'we', 'because', 'I’ve'],
#  'how': ['to',
#   'can',
#   'proposals',
#   'rotten',
#   'we',
#   'to',
#   'much',
#   'invincible',
#   'a',
#   'there’s,',
#   'it'],
#  'declutter': ['my'],
#  'home': ['to', 'in', 'all', 'and', 'together.'],
#  'achieve': ['inner', 'my'],
#  'optimum': ['level', 'level'],
#  'level': ['of', 'of'],
#  'success.': ['That’s'],
#  '30s': ['is'],
#  'about.': ['How'],
#  'How': ['can', 'did', 'did', 'did'],
#  'around?': ['I’m', 'Help'],
#  'horrible': ['person,', 'toilet'],
#  'person,': ['I’m'],
#  'happy': ['with'],
#  'am,': ['how'],
#  'Help': ['me,'],
#  'me,': ['Tony',
#   'he’s',
#   'this',
#   'but',
#   'I',
#   'because',
#   '“Oh,',
#   'I’m',
#   'out',
#   'with'],
#  'Tony': ['Robbins,'],
#  'Robbins,': ['help'],
#  'help': ['me!\nI', 'her', 'you', 'as'],
#  'me!\nI': ['have'],
#  'hoarding': ['problem,', 'goes', 'problem'],
#  'problem,': ['which'],
#  'which': ['I’m',
#   'is',
#   'means',
#   'would',
#   'their',
#   'is',
#   'is',
#   'means',
#   'subsequently'],
#  'hoping': ['is', 'that'],
#  'center': ['of'],
#  'other': ['problems.', 'homeless', 'day.', 'shitty'],
#  'problems.': ['I’m'],
#  'if': ['the',
#   'he',
#   'you',
#   'you',
#   'I',
#   'you',
#   'you',
#   'I',
#   'you',
#   'I’m',
#   'I',
#   'he',
#   'you',
#   'I',
#   'I'],
#  'goes': ['away,', 'down'],
#  'away,': ['the'],
#  'disappear.': ['I', 'That’s'],
#  'problem': ['because'],
#  'mom': ['is', 'got', 'is', 'is'],
#  'from': ['a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'Pier',
#   'Harvard',
#   'the',
#   'the',
#   'having',
#   'having',
#   'the',
#   'this',
#   'pedestrians',
#   'their',
#   'a',
#   'holding',
#   'bacteria',
#   'Harvard'],
#  'third': ['world', 'grade,', 'world'],
#  'world': ['country', '♪', 'with', 'country,'],
#  'country': ['and', 'and'],
#  'she': ['taught', 'refused', 'was', 'wrote', 'knows', 'is', 'was', 'said,'],
#  'taught': ['me'],
#  'never': ['throw', 'know', 'know', 'finish', 'finish', 'called'],
#  'throw': ['away', 'up.', 'up'],
#  'away': ['anything,', 'from', 'at'],
#  'anything,': ['because'],
#  'dictator’s': ['gonna'],
#  'overtake': ['the'],
#  'snatch': ['all'],
#  'wealth.': ['So,'],
#  'better': ['hold', 'looking', 'just'],
#  'hold': ['onto', 'onto'],
#  'onto': ['that', 'the', 'his'],
#  'retainer': ['from'],
#  'grade,': ['’cause'],
#  'might': ['come', 'need', 'mean'],
#  'come': ['in', 'out,', 'up', 'out,', 'out', 'home,', 'with', 'out'],
#  'handy': ['as'],
#  'as': ['a',
#   'a',
#   'an',
#   'women',
#   'much',
#   'they',
#   'a',
#   'many',
#   'possible',
#   'the',
#   'freaky',
#   'me.',
#   'a',
#   'old',
#   'her.',
#   'wet',
#   'it',
#   'pent-up,',
#   'angry',
#   'possible.',
#   'leverage',
#   'it'],
#  'shovel': ['when'],
#  'busy': ['stuffing', 'in', 'makin’'],
#  'stuffing': ['gold'],
#  'gold': ['up'],
#  'butt': ['and', 'hole.', 'with', 'hole', 'cheeks', 'hole.'],
#  'running': ['away'],
#  'Communists.\nThe': ['last'],
#  'last': ['time',
#   'forever.',
#   'boyfriend',
#   'time',
#   'year,',
#   'boyfriend',
#   'year,'],
#  'time': ['I', 'shitting', 'I', 'I', 'you'],
#  'was': ['at',
#   'trying',
#   'like',
#   'so',
#   'this',
#   'like',
#   'like',
#   'like,',
#   'like,',
#   'like,',
#   'that,',
#   'attending',
#   'like,',
#   'a',
#   'like,',
#   'living',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'Cuban',
#   'like,',
#   'like,',
#   'like,',
#   'legit,',
#   'gonna',
#   'ready.',
#   'ripe.',
#   'rotten.',
#   'free?',
#   'like,',
#   'you.',
#   'like,',
#   'like,',
#   'like,',
#   'very',
#   'magical.',
#   'to',
#   'sliced',
#   'sliced',
#   'like,',
#   'like,',
#   'gonna',
#   'starting',
#   'just',
#   'so',
#   'in',
#   'OK,',
#   'clearly',
#   'that',
#   'Easter',
#   'so',
#   'about',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   '18',
#   'like,',
#   'like,',
#   '$70,000'],
#  'San': ['Francisco,', 'Francisco,'],
#  'Francisco,': ['I', 'when'],
#  'trying': ['to', 'to', 'to', 'to', 'to', 'to', 'to', 'to'],
#  'her': ['get',
#   'to',
#   'book',
#   'Lululemon',
#   'butt.”',
#   'nipples,',
#   'pussy',
#   'white',
#   'I'],
#  'rid': ['of'],
#  'shit.': ['Don’t', 'My', 'You’re', 'It’s'],
#  'Don’t': ['ever', 'try', 'your', 'kill', 'feel'],
#  'ever': ['do', 'actually', 'happened'],
#  'do': ['that',
#   'know…',
#   'fancy',
#   'yoga.',
#   'ayahuasca',
#   'silent',
#   'shit',
#   'it.',
#   'it',
#   'anything.',
#   'it!',
#   'anything.”',
#   'write',
#   'that.',
#   'whatever',
#   'that.',
#   'all',
#   'anal',
#   'it.',
#   'get',
#   'whatever',
#   'this',
#   'that',
#   'it',
#   'in',
#   'some',
#   'whatever',
#   'for',
#   'shit',
#   'mushrooms',
#   'a',
#   'it?',
#   'you'],
#  'mom.': ['It', 'People'],
#  'It': ['was',
#   'was',
#   'was',
#   'cost',
#   'could',
#   'was',
#   'happened',
#   'happened',
#   'basically',
#   'was',
#   'tells',
#   'was,',
#   'makes'],
#  'worst': ['experience', 'thing'],
#  'experience': ['of', 'some'],
#  'life.': ['It', 'And'],
#  'emotional.': ['We'],
#  'were': ['screaming',
#   'all',
#   'in',
#   'hipsters,',
#   'getting',
#   'done,',
#   'like,',
#   'discouraging',
#   'like,',
#   '18',
#   'alarmingly',
#   'suppositories,',
#   'trying',
#   'like,',
#   'the'],
#  'screaming': ['and'],
#  'fighting': ['and'],
#  'yelling': ['and'],
#  'came': ['to', 'outta', 'out'],
#  'climax': ['when'],
#  'refused': ['to', 'to'],
#  'let': ['go', 'it', 'their'],
#  'Texas': ['Instruments'],
#  'Instruments': ['TI-82…'],
#  'TI-82…': ['manual.'],
#  'manual.': ['The', 'She'],
#  'She': ['don’t', 'doesn’t'],
#  'know…': ['where', 'that', 'freaked'],
#  'calculator': ['is.', 'is.', 'that'],
#  'is.': ['Those', 'It'],
#  'Those': ['of'],
#  'under': ['25'],
#  '25': ['probably'],
#  'probably': ['don’t', 'Pinterested', 'one', 'looked'],
#  'bamboozled': ['my'],
#  'generation.': ['We', 'You'],
#  'required': ['to'],
#  'buy': ['it'],
#  'we': ['were',
#   'had,',
#   'had…',
#   'were',
#   'were',
#   'spend',
#   'pay',
#   'eat',
#   'eat',
#   'do…',
#   'are',
#   'have',
#   'as',
#   'better',
#   'have',
#   'had',
#   'walk',
#   'just',
#   'live',
#   'wouldn’t',
#   'got',
#   'got',
#   'bought',
#   'die.'],
#  'eight': ['grade.'],
#  'grade.': ['It'],
#  'cost': ['like'],
#  '$200.': ['And'],
#  'And': ['everybody',
#   'my',
#   'I',
#   'the',
#   'I',
#   'I',
#   'we–',
#   'then',
#   'I',
#   'you',
#   'then',
#   'we',
#   'I',
#   'then',
#   'on',
#   'the',
#   'so,',
#   'then',
#   'look,',
#   'her',
#   'then,',
#   'they’re',
#   'they’ll',
#   'you',
#   'you’re',
#   'then',
#   'then',
#   'just',
#   'I',
#   'what',
#   'they’re',
#   'I',
#   'you',
#   'it’s',
#   'then,',
#   'I’m',
#   'I',
#   'all',
#   'their',
#   'they',
#   'you',
#   'then,',
#   'she',
#   'when',
#   'it–',
#   'it',
#   'a',
#   'I',
#   'then,',
#   'then,',
#   'I',
#   'they',
#   'then,',
#   'then,',
#   'then,',
#   'then',
#   'a',
#   'everything',
#   'the',
#   'I',
#   'then',
#   'I',
#   'most',
#   'he',
#   'I',
#   'just',
#   'it',
#   'then,',
#   'I',
#   'I',
#   'then,',
#   'me,',
#   'now,'],
#  'everybody': ['thought', 'doesn’t', 'thought'],
#  'thought': ['it', 'they', 'it'],
#  'Judy': ['Jetson’s'],
#  'Jetson’s': ['laptop'],
#  'laptop': ['from'],
#  'future.': ['All', '‘Cause'],
#  'All': ['because', 'of', 'the', 'right,'],
#  'what?': ['It'],
#  'graph.': ['It'],
#  'Tesla': ['of'],
#  'time.': ['And', 'And', 'And', 'It'],
#  'emotional': ['about'],
#  'manual': ['and'],
#  '“You': ['never', 'need', 'need', 'have', 'look.”', 'watch'],
#  'need': ['this.”',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'to',
#   'children',
#   'to',
#   'you',
#   'to'],
#  'this.”': ['And'],
#  '“But…': ['I'],
#  'clean': ['all'],
#  'die.”': ['“And'],
#  '“And': ['I’m', 'all'],
#  'be': ['a',
#   'a',
#   'nice',
#   'with',
#   'racist',
#   'exfoliated',
#   'providing',
#   'made',
#   'no',
#   'like,',
#   'like,',
#   'like,',
#   'a',
#   'all',
#   'abused',
#   'roughed',
#   'out',
#   'sure',
#   'out',
#   'the',
#   'able',
#   'like,',
#   'there',
#   'there',
#   'one',
#   'that',
#   'storyboarding',
#   'able',
#   'like,',
#   'as',
#   'like,',
#   'like,',
#   'pregnant',
#   'seven',
#   'asked',
#   'considered',
#   'considered',
#   'one'],
#  'procrastinator': ['anymore.'],
#  'anymore.': ['Because', 'I', 'I', 'I’ve', 'Since', 'I’m', 'I’m', 'I’m'],
#  'according': ['to', 'to'],
#  'Deepak-Oprah,': ['that’s'],
#  'way': ['for', 'out', 'of', 'to…”', 'more'],
#  'success.”': ['I'],
#  'grew': ['up', 'up', 'up', 'up'],
#  'past': ['year.', 'year'],
#  'married.': ['Yeah.', 'I’m'],
#  'Yeah.': ['To', 'Yes.', 'Which', 'It’s'],
#  'To': ['a'],
#  'man': ['who', 'and', 'has', 'a', 'at', 'all', 'is'],
#  'who': ['now',
#   'is',
#   'like',
#   'are',
#   'wrote',
#   'are',
#   'have',
#   'recycles',
#   'are',
#   'have',
#   'else',
#   'tries',
#   'trapped'],
#  'now': ['has', 'for', 'we’re'],
#  'lucky': ['guy.', 'girl,'],
#  'guy.': ['He'],
#  'He': ['gave',
#   'was',
#   'was',
#   'grew',
#   'was',
#   'proposed!”',
# ...
#   'a',
#   'sure',
#   'him'],
#  'dude': ['believe', 'you', 'eats', 'and', 'named'],
#  'believe': ['that', 'that.”', 'he', 'that'],
#  'secret': ['garden.”'],
#  'garden.”': ['When,'],
#  'When,': ['really,'],
#  'really,': ['it’s', 'you', 'I'],
#  'public': ['park…'],
#  'park…': ['…that'],
#  '…that': ['has', 'blows'],
#  'hosted': ['many'],
#  'many': ['reggae', 'more', 'men'],
#  'reggae': ['fests…'],
#  'fests…': ['…and'],
#  '…and': ['has', 'half-jungle'],
#  'accidentally': ['let…'],
#  'let…': ['two'],
#  'homeless': ['people', 'or', 'friends,', 'dude!'],
#  'people': ['inside.',
#   'are',
#   'all',
#   'don’t',
#   'until',
#   'doing',
#   'were',
#   'will'],
#  'hipsters,': ['OK?'],
#  'store': ['Urban'],
#  'Urban': ['Outfitters'],
#  'Outfitters': ['has'],
#  'made': ['things', 'into', 'it,', 'me', 'you'],
#  'things': ['very', 'like'],
#  'confusing…': ['for'],
#  'hipster?': ['Is'],
#  'Is': ['that'],
#  'beard': ['for'],
#  'fashion': ['or'],
#  'warmth?': ['It'],
#  'happened': ['to…', 'in', 'to'],
#  'to…': ['It', 'Now,'],
#  'living': ['there,'],
#  'there,': ['and', 'through', 'OK?'],
#  'guy': ['in'],
#  'broad': ['daylight'],
#  'daylight': ['and'],
#  'had,': ['like,'],
#  'had…': ['We'],
#  'had': ['so',
#   'been',
#   'this',
#   'been',
#   'this',
#   'tried',
#   'it',
#   'to',
#   'a',
#   'to',
#   'the',
#   'this',
#   'a',
#   'such',
#   'this',
#   'to',
#   'to',
#   'to',
#   'to',
#   'a',
#   'a',
#   'one,',
#   'the',
#   'dated'],
#  'chemistry.': ['He'],
#  '“Hey,': ['wassup?”', 'can', 'I', 'hey!', 'can'],
#  'wassup?”': ['I'],
#  '“Wassup?”': ['And'],
#  'we–': ['The'],
#  'next': ['thing', 'century'],
#  'knew,': ['we'],
#  'back': ['of', 'out', 'in', 'of', 'in'],
#  'Volvo.': ['And'],
#  'after': ['we', 'they'],
#  'done,': ['he'],
#  'drop': ['me'],
#  'off?”': ['I'],
#  '“Where?”': ['He'],
#  '“At': ['the'],
#  'park.”': ['And'],
#  'dropped': ['him'],
#  'off': ['at', 'and', 'of'],
#  'Golden': ['Gate'],
#  'Gate': ['Park'],
#  'Park': ['and'],
#  'watched': ['him'],
#  'run': ['into', 'over'],
#  'middle': ['with'],
#  'friends,': ['and', 'when', 'dead.', 'dead.', 'dead.'],
#  'no!”': ['“I'],
#  '“I': ['just',
#   'could',
#   'did',
#   'saw',
#   'just',
#   'gotta',
#   'don’t',
#   'changed',
#   'slime',
#   'am'],
#  'dude!': ['Again!”'],
#  'Again!”': ['My'],
#  'husband': ['is',
#   'and',
#   'recently.',
#   'is',
#   'to',
#   'and',
#   'dies.”',
#   'isn’t',
#   'and',
#   'a',
#   'down',
#   'will',
#   'for',
#   'on,',
#   'was'],
#  'Asian.': ['Which', 'Yeah!'],
#  'Which': ['a', 'is…', 'means', 'is', 'is', 'he’s', 'is'],
#  'shocked': ['by,'],
#  'by,': ['because,'],
#  'usually,': ['Asian-American'],
#  'Asian-American': ['women', 'men', 'brothers'],
#  'women': ['who,',
#   'all',
#   'should',
#   'had',
#   'get',
#   'get',
#   'who',
#   'who',
#   'who',
#   'would',
#   'won’t',
#   'tried'],
#  'who,': ['like,'],
#  'know,': ['wear',
#   'because',
#   'white',
#   'it’s',
#   'just',
#   'learning',
#   'I',
#   'squeeze',
#   'it’s–',
#   'and',
#   'a',
#   'is',
#   'I–',
#   'they',
#   'I–'],
#  'wear': ['these', 'that'],
#  'these': ['kinda',
#   'bitches.',
#   'Chinese',
#   'women',
#   'boring,',
#   'other',
#   'hormone',
#   'ovulation'],
#  'kinda': ['glasses'],
#  'glasses': ['and'],
#  'opinions,': ['they'],
#  'date': ['white'],
#  'white': ['dudes.',
#   'dude',
#   'dude,',
#   'dudes,',
#   'dude.',
#   'dude',
#   'man!',
#   'people',
#   'people.',
#   'friends,',
#   'hippie'],
#  'dudes.': ['You'],
#  'any': ['hipster', 'moment,', 'real', 'sort', 'black', 'given'],
#  'hipster': ['neighborhood'],
#  'neighborhood': ['in'],
#  'major': ['city'],
#  'city': ['in'],
#  'America': ['and'],
#  'Yoko': ['Ono'],
#  'Ono': ['factory.'],
#  'factory.': ['It’s…'],
#  'It’s…': ['too', 'amazing.', 'It’s'],
#  'too': ['much.', 'nice.', 'old', 'late', 'stupid', 'funky,'],
#  'much.': ['I', 'For'],
#  'what’s': ['wrong', 'gonna', 'wrong'],
#  'wrong': ['with', 'with'],
#  'it,': ['you', 'you', 'and', 'that', 'when', 'just…'],
#  'being': ['with', 'the', 'courageous.'],
#  'feel': ['very…',
#   'very',
#   'like',
#   'more',
#   'like',
#   'like',
#   'rushed',
#   'like',
#   'so',
#   'bad,'],
#  'very…': ['You'],
#  'picturesque': ['when'],
#  'dude,': ['you', 'focus', 'and'],
#  'know.': ['You'],
#  'Wes': ['Anderson'],
#  'Anderson': ['movie'],
#  'movie': ['or'],
#  'dudes,': ['they'],
#  'teach': ['you'],
#  'cool': ['stuff', 'stuff'],
#  'stuff': ['like', 'like'],
#  'voting': ['and'],
#  'recycling,': ['and'],
#  'disturbing': ['documentaries.'],
#  'documentaries.': ['They'],
#  'introduce': ['you'],
#  'very,': ['you', 'very'],
#  'hot': ['hookin’'],
#  'hookin’': ['up'],
#  'dude.': ['I', 'Do', 'That’s–'],
#  'mean,': ['nothing'],
#  'nothing': ['makes', 'for'],
#  'makes': ['me', 'me', 'sense,'],
#  'more': ['powerful',
#   'like',
#   'options',
#   'doo',
#   'money',
#   'successful',
#   'to',
#   'women',
#   'handsome'],
#  'powerful': ['than'],
#  'eats': ['my'],
#  'pussy.': ['Oh,'],
#  'Oh,': ['my', 'my', 'you', 'my', 'my', 'my'],
#  'God.': ['I', 'It’s', 'That’s', 'I'],
#  'absorbing': ['all'],
#  'privilege': ['and'],
#  'entitlement…': ['…you'],
#  '…you': ['know,'],
#  'right': ['there,', 'now!', 'moment', 'turn–', 'there.', 'after'],
#  'through': ['the', 'Southeast', 'and', 'a', 'it.', 'a'],
#  'money': ['hole', 'if'],
#  'hole': ['and', 'feels'],
#  'just…': ['And', 'Let’s', '“I', 'And'],
#  'also,': ['he’s'],
#  'vulnerable': ['down'],
#  'down': ['there.', 'there,', 'your', 'immediately', 'in', 'so', 'with'],
#  'there.': ['I’m,', 'I', 'But'],
#  'I’m,': ['like,', 'like,'],
#  'crush': ['your'],
#  'head': ['at', 'shredding', 'and', 'for'],
#  'moment,': ['white', 'you'],
#  'man!': ['I'],
#  'kill': ['you', 'me!'],
#  'now!': ['Crush'],
#  'Crush': ['those', 'while'],
#  'those': ['brains!', 'comments.', 'green', 'old', 'doctor', 'crazy'],
#  'brains!': ['Colonize'],
#  'Colonize': ['the'],
#  'colonizer!”': ['You'],
#  'know?\nBut': ['I'],
#  'think': ['that',
#   'my',
#   'feminism',
#   'we',
#   'it’s',
#   'of',
#   'about',
#   'that’s',
#   'so.',
#   'I’m'],
#  'marriage,': ['it', 'because'],
#  'nice': ['to'],
#  'somebody': ['of', 'closes', 'closes'],
#  'own': ['race.', 'goddamn'],
#  'race.': ['The'],
#  'advantage': ['is'],
#  'home…': ['and'],
#  'racist': ['together.'],
#  'together.': ['You', 'And,'],
#  'say': ['whatever', 'to', 'be'],
#  'whatever': ['you', 'they', 'you', 'the'],
#  'like!': ['You'],
#  'explain': ['shit.'],
#  'half-Filipino,': ['half-Japanese.'],
#  'half-Japanese.': ['I’m'],
#  'half-Chinese': ['and', 'and'],
#  'half-Vietnamese.': ['And', 'So,'],
#  'spend': ['100'],
#  '100': ['percent'],
#  'percent': ['of', 'of', 'spoken'],
#  'our': ['time', 'first', 'Buddha', 'careers.', 'day', 'society', 'first'],
#  'shitting': ['on'],
#  'Korean': ['people.'],
#  'amazing.': ['It’s'],
#  'love': ['is', 'to', 'it', 'my', 'it', 'of'],
#  'built': ['on,'],
#  'on,': ['you', 'you', 'like,'],
#  'know?\nMy': ['last'],
#  'boyfriend': ['was', 'because'],
#  'Cuban': ['and'],
#  'would': ['shit',
#   'double',
#   'not',
#   'have',
#   'I',
#   'crash.”',
#   'simultaneously',
#   'explode.',
#   'be',
#   'be',
#   'inevitably',
#   'only',
#   'be',
#   'come',
#   'just',
#   'close',
#   'jump',
#   'just',
#   'turn',
#   'just',
#   'talk'],
#  'Mexican': ['people', 'friends,'],
#  '“Hold': ['it.'],
#  'guys': ['aren’t', 'know', 'about', 'need', 'had.”', 'can', 'doin’'],
#  'aren’t': ['Mexican?”'],
#  'Mexican?”': ['Asian-American'],
#  'underrated.': ['I'],
#  'why': ['people', 'you', 'are', 'we’re', 'I’m'],
#  'sexiest.': ['Asian', 'They'],
#  'Asian': ['men', 'men,', 'people.', 'female', 'woman,', 'don’t', 'ladies'],
#  'no': ['body', 'body', 'job.', 'unpredictable', 'kid', 'shame.'],
#  'hair': ['from'],
#  'neck': ['down.'],
#  'down.': ['It’s', 'I', 'I', 'People'],
#  'making': ['love'],
#  'dolphin.': ['Oh,'],
#  'smooth,': ['just'],
#  'slip': ['and'],
#  'slide.': ['Just'],
#  'Just': ['black', 'sneak', 'give', 'give', 'choke', 'try'],
#  'black': ['fish,', 'friends.'],
#  'fish,': ['Tilikum,'],
#  'Tilikum,': ['all'],
#  'bed': ['every'],
#  'every': ['night,',
#   'day.”',
#   'single',
#   'day.',
#   'day.',
#   'day…',
#   'day',
#   'single'],
#  'night,': ['you', 'everybody.'],
#  'know?': ['Ooh-wee.',
#   'Maybe',
#   'I',
#   'Especially',
#   'My',
#   'Like,',
#   'I',
#   'I',
#   'I',
#   'And,',
#   'Your',
#   'And'],
#  'Ooh-wee.': ['You'],
#  'mess': ['with'],
#  'Jewish': ['dude', 'male'],
#  'afterwards.': ['It’s', 'I'],
#  'red': ['and', 'light'],
#  'inflamed': ['and'],
#  'ask': ['to', 'for,'],
#  'exfoliated': ['today.”'],
#  'today.”': ['“This'],
#  '“This': ['is'],
#  'J-date,': ['more'],
#  'loofah': ['date.'],
#  'date.': ['Thanks'],
#  'Thanks': ['for'],
#  'rug': ['burn,'],
#  'burn,': ['Avi.”'],
#  'Avi.”': ['And'],
#  'men,': ['no'],
#  'odor.': ['None.'],
#  'None.': ['They'],
#  'smell': ['like', 'my', 'my', 'my', 'my', 'my'],
#  'responsibility.': ['That’s'],
#  'umami': ['flavor'],
#  'flavor': ['comes'],
#  'comes': ['from.\nI', 'out.', 'out', 'out,', 'to'],
#  'from.\nI': ['think'],
#  'unspoken': ['understanding,'],
#  'understanding,': ['uh,'],
#  'between': ['each', 'your'],
#  'each': ['other,', 'other.'],
#  'other,': ['because'],
#  'half-Filipino': ['and'],
#  'half-Japanese': ['and'],
#  'we’re': ['both', 'too', 'expected', 'so', 'such', 'trying', 'hippies,'],
#  'both': ['half-fancy', 'total,', 'are'],
#  'half-fancy': ['Asian…'],
#  'Asian…': ['…and'],
#  'half-jungle': ['Asian.'],
#  'Yeah!': ['You', 'Never'],
#  'difference.': ['The'],
#  'fancy': ['Asians', 'things'],
#  'Asians': ['are', 'host'],
#  'Chinese,': ['the'],
#  'Japanese.': ['They'],
#  'host': ['Olympics.', 'diseases.'],
#  'Olympics.': ['Jungle'],
#  'Jungle': ['Asians'],
#  'diseases.': ['It’s…'],
#  'different.': ['But', 'It’s'],
#  'East': ['Coast,'],
#  'Coast,': ['going'],
#  'going': ['to', 'to', 'back', 'through', 'through', 'to'],
#  'private': ['school,', 'school,', 'school'],
#  'school,': ['playing', 'too.'],
#  'playing': ['lacrosse,', 'chess', 'dumb', 'Candy'],
#  'lacrosse,': ['uh,'],
#  'learning': ['Latin'],
#  'Latin': ['and'],
#  'chess': ['and'],
#  'rugby.': ['He'],
#  'Filipino': ['Carlton,'],
#  'Carlton,': ['OK?'],
#  'didn’t': ['know', 'think', 'know', 'know'],
#  'anything': ['about'],
#  'Vietnamese': ['people'],
#  'dates,': ['he'],
#  'took': ['me', 'it', 'me'],
#  'restaurant': ['on', 'deaf'],
#  'west': ['side'],
#  'side': ['of', 'from', 'effect'],
#  'Los': ['Angeles'],
#  'Angeles': ['called'],
#  'called': ['Pho', 'Lean', 'bossy.'],
#  'Pho': ['Show.'],
#  'Show.': ['He'],
#  '“It’s': ['authentic', 'not'],
#  'authentic': ['Vietnamese.'],
#  'Vietnamese.': ['I'],
#  'read': ['about'],
#  'Yelp!”': ['I'],
#  'authentic,': ['OK?”'],
#  'OK?”': ['You', '‘Cause', 'And', 'And'],
#  'tell,': ['first', 'but'],
#  'name,': ['’cause'],
#  'number': ['in'],
#  'Second': ['of'],
#  'all,': ['you'],
#  'bathroom.': ['If'],
#  'legit,': ['the'],
#  'bathroom': ['would'],
#  'double': ['as', 'standard'],
#  'supply': ['closet.'],
#  'closet.': ['When'],
#  'When': ['I',
#   'you',
#   'I',
#   'I’ve',
#   'can',
#   'can',
#   'my',
#   'in–',
#   'you’re',
#   'somebody',
#   'somebody',
#   'I',
#   'it’s'],
#  'pee,': ['I'],
#  'gallons': ['of'],
#  'bleach,': ['an'],
#  'ATM': ['machine'],
#  'machine': ['and'],
#  'grandma': ['with'],
#  'glaucoma': ['napping'],
#  'napping': ['in'],
#  'corner.': ['And'],
#  'wait': ['staff', 'to'],
#  'staff': ['here', 'and'],
#  'nice.': ['We'],
#  'leave': ['this', 'without', 'you,'],
#  'deaf': ['and'],
#  'emotionally': ['abused.'],
#  'abused.': ['I'],
#  'too.': ['Him', 'We', 'But', 'They'],
#  'Him': ['and', 'and'],
#  'total,': ['like,'],
#  'school': ['Asians.'],
#  'Asians.': ['We'],
#  'big': ['hippies,', 'fantasy', 'impact'],
#  'hippies,': ['too.', 'I’d'],
#  'backpack': ['through'],
#  'Southeast': ['Asia.'],
#  'Asia.': ['We'],
#  'yoga.': ['We'],
#  'ayahuasca': ['ceremonies.'],
#  'ceremonies.': ['We'],
#  'silent': ['meditation'],
#  'meditation': ['retreats.'],
#  'retreats.': ['That’s'],
#  'pay': ['$800', 'for'],
#  '$800': ['to'],
#  'shut': ['up', 'up!”', 'the'],
#  'weekend.': ['We'],
#  'gluten-free,': ['which'],
#  'means': ['we', 'I', 'the', 'you’re'],
#  'bread': ['that', 'that’s'],
#  'tastes': ['like', 'when'],
#  'free-range': ['Chewbacca.'],
#  'Chewbacca.': ['We'],
#  'lesbian': ['bread'],
#  'like…': ['…a'],
#  '…a': ['thousand'],
#  'thousand': ['percent'],
#  'daily': ['fiber…', 'basis.', 'basis…'],
#  'fiber…': ['and'],
#  '20': ['percent'],
#  'spoken': ['word'],
#  'word': ['poetry.', '“bossy”', '“bossy,”'],
#  'poetry.': ['When'],
#  'queef': ['a'],
#  'shitty': ['poem', 'dads', 'mom.'],
#  'poem': ['about…'],
#  'about…': ['…supporting'],
#  '…supporting': ['Caitlyn'],
#  'Caitlyn': ['Jenner'],
#  'Jenner': ['or'],
#  'whatever.': ['And'],
#  'so,': ['it’s', 'in', 'motherfucker,'],
#  'funny,': ['right,'],
#  'Asian,': ['too.'],
#  'sometimes,': ['all'],
#  'hippy-dippy': ['shit'],
#  'do…': ['makes'],
#  'doing': ['an', 'anything.', 'jack', 'it.'],
#  'impression': ['of'],
#  'Like,': ['we', 'you', '“I', 'I’m', '“You,'],
#  'Chinese': ['scrolls', 'ladies', 'ladies,'],
#  'scrolls': ['up'],
#  'wall…': ['and'],
#  'neither': ['of'],
#  'us': ['know', 'to,'],
#  'mean.': ['We’re'],
#  'We’re': ['like,', 'like,'],
#  'seems': ['to', 'to'],
#  'well': ['with'],
#  'Buddha': ['piggy'],
#  'piggy': ['bank'],
#  'bank': ['from'],
#  'Pier': ['1'],
#  '1': ['Imports.'],
#  'Imports.': ['That'],
#  'providing': ['some'],
#  'some': ['good', 'risk', 'useful', 'lame', 'point,', 'of'],
#  'good': ['feng', 'in', 'night,'],
#  'feng': ['shui'],
#  'shui': ['for'],
#  'house.': ['Him', 'Skin', '“Hey,'],
#  'four': ['years', 'days'],
#  'years': ['and', 'old,', 'old,'],
#  'I–': ['I', 'I–', 'I,', 'I,'],
#  'sneaking': ['suspicion'],
#  'suspicion': ['that'],
#  'propose…': ['because…'],
#  'because…': ['I', 'they’re'],
#  'pressuring': ['him'],
#  'wacky': ['women’s'],
#  'intuition.': ['That’s'],
#  'proposals': ['really'],
#  'work,': ['OK?', 'we'],
#  'woman': ['has', 'is', 'wants', 'who'],
#  'incept': ['the'],
#  'idea': ['into'],
#  'man’s': ['head.', 'eye'],
#  'head.': ['First'],
#  'First': ['passively'],
#  'passively': ['and'],
#  'doesn’t': ['get', 'see', 'have', 'have', 'believe'],
#  'message,': ['extremely'],
#  'extremely': ['aggressively.', 'itchy.'],
#  'aggressively.': ['You'],
#  'threaten': ['to'],
#  'without': ['ever'],
#  'actually': ['leaving,'],
#  'leaving,': ['because'],
#  'old': ['and', 'as', 'Chinese'],
#  'late': ['to'],
#  'there': ['and', 'and', 'is', 'for', 'for', 'would'],
#  'new': ['man', 'world'],
#  'start': ['the', 'all', 'watching'],
#  'manipulation': ['cycle'],
#  'cycle': ['all'],
#  'again.': ['So,', 'And', 'It’s', 'But'],
#  '“I’m': ['just', 'gonna', 'just'],
#  'stick': ['with', 'your'],
#  'focus': ['on'],
#  'trapping': ['this'],
#  'nag': ['the'],
#  'outta': ['him', 'nowhere.'],
#  'becomes': ['weak'],
#  'weak': ['and'],
#  'caves': ['in'],
#  'gets': ['fed', 'very'],
#  'fed': ['up'],
#  '“Shut': ['the'],
#  'up!': ['Fine,'],
#  'Fine,': ['will'],
#  'marry': ['me?”', 'him'],
#  'me?”': ['And'],
#  'afterwards,': ['the', 'and'],
#  'always,': ['like,'],
#  'God!': ['He', 'It’s', 'And'],
#  'proposed!”': ['“It'],
#  '“It': ['came'],
#  'nowhere.': ['And', 'And'],
#  'look,': ['he'],
#  'exact': ['ring'],
#  'ring': ['I'],
#  'wanted.': ['How', 'I’m'],
#  'Maybe': ['he', 'because'],
#  'Pinterest': ['page', 'page…'],
#  'page': ['or'],
#  'something…': ['that'],
#  'sent': ['to'],
#  'best': ['friend,', 'you'],
#  'friend,': ['that'],
#  'send': ['to'],
#  'day.”': ['Let'],
#  'Let': ['me', 'me'],
#  'page…': ['he’s'],
#  'Pinterested': ['in'],
#  'engaged': ['on'],
#  'Saturday.': ['I'],
#  'bought': ['my', 'me', 'our'],
#  'dress': ['the'],
#  'following': ['Tuesday…'],
#  'Tuesday…': ['because'],
#  'tried': ['it', 'to', 'to'],
#  '2012.': ['I'],
#  'ready.': ['I'],
#  'ripe.': ['I'],
#  'rotten.': ['I'],
#  'banana': ['bread.'],
#  'bread.': ['That’s'],
#  'rotten': ['I'],
#  'was.': ['People'],
#  'People': ['are', 'praise', 'don’t'],
#  'always': ['very', 'feel', 'catch', 'means', 'tell', 'wanted.'],
#  'surprised': ['at'],
#  'how,': ['off-stage,'],
#  'off-stage,': ['with'],
#  'completely': ['different'],
#  'different': ['person.', 'holes,', 'people.'],
#  'person.': ['You–'],
#  'You–': ['Like,'],
#  'recognize': ['my', 'your'],
#  'personality': ['at'],
#  'him.': ['With', 'But'],
#  'With': ['him,'],
#  'soft,': ['and,'],
#  'nurturing': ['and'],
#  'domestic.': ['We’ve'],
#  'We’ve': ['been'],
#  'years,': ['and', 'I’ve'],
#  'I’ve': ['packed', 'been', 'been', 'asked', 'picked', 'been'],
#  'packed': ['his'],
#  'lunch': ['every'],
#  'single': ['day.', 'night.'],
#  'day.': ['Yeah.', 'Which', 'Housewives,', 'This'],
#  'he’d': ['become'],
#  'become': ['dependent', 'the', 'a', 'this', 'some'],
#  'dependent': ['on'],
#  'graduated': ['from', 'from'],
#  'School,': ['and', 'the'],
#  'work': ['anymore.',
#   'anymore.',
#   'anymore.',
#   'at',
#   'because',
#   'on',
#   'anymore',
#   'anymore.'],
#  'don’t.': ['I'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# 'Tastes when they look like you’re a ban on the smart thing, which would jump.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %% [markdown]
# Creating a dictionary for john

# %%
john_text = data.transcript.loc['john']
john_text[:500]
# Out:
# 'All right, Petunia. Wish me luck out there. You will die on August 7th, 2037. That’s pretty good. All right. Hello. Hello, Chicago. Nice to see you again. Thank you. That was very nice. Thank you. Look, now, you’re a wonderful crowd, but I need you to keep your energy up the entire show, okay? Because… No, no, no. Thank you. Some crowds… some crowds, they have big energy in the beginning and then they run out of places to go. So… I don’t judge those crowds, by the way, okay? We’ve all gone too b'

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for john's routine, take a look at it
john_dict = markov_chain(john_text)
john_dict
# Out:
# {'All': ['right,', 'right.', 'right,', 'right,', 'right,'],
#  'right,': ['Petunia.',
#   'proceed.”',
#   'it’s',
#   'well,',
#   'all',
#   'all',
#   'we’re',
#   'don’t'],
#  'Petunia.': ['Wish', 'She’s', 'You'],
#  'Wish': ['me'],
#  'me': ['luck',
#   'this',
#   'my',
#   'and',
#   'all',
#   'ask',
#   'my',
#   'a',
#   'very',
#   'and',
#   'and',
#   'and',
#   'to',
#   'now',
#   'and',
#   'that,',
#   'by',
#   'wrong,',
#   'as',
#   'or',
#   'again.”',
#   'one',
#   'on',
#   'break',
#   'walk,',
#   'up',
#   'that',
#   'that',
#   'that',
#   'that',
#   'forward',
#   'like',
#   'towards',
#   'in',
#   'in'],
#  'luck': ['out'],
#  'out': ['there.',
#   'of',
#   'of',
#   'on',
#   'like',
#   'molestation',
#   'there',
#   'of',
#   'laughing.',
#   'with',
#   'with',
#   'there.',
#   'on',
#   'to',
#   'of',
#   'when',
#   'so',
#   'in',
#   'to',
#   'that',
#   'after',
#   'with…',
#   'of',
#   'a',
#   'there',
#   'of',
#   'in',
#   'in',
#   'that',
#   'about',
#   'that'],
#  'there.': ['You', 'You', 'And', 'Walter', 'Everybody.'],
#  'You': ['will',
#   'get',
#   'know',
#   'ever',
#   'know',
#   'really',
#   'just',
#   'have',
#   'just',
#   'Don’t',
#   'don’t',
#   'know,',
#   'know,',
#   'are',
#   'have',
#   'should',
#   'should',
#   'have',
#   'remember',
#   'know?',
#   'remember',
#   'know?',
#   'can',
#   'know?',
#   'know,'],
#  'will': ['die',
#   'fit',
#   'be,',
#   'be',
#   'point',
#   'be',
#   'watch',
#   'take',
#   'not',
#   'sometimes',
#   'ever'],
#  'die': ['on', 'every'],
#  'on': ['August',
#   'stage.',
#   'this',
#   'an',
#   'and',
#   'the',
#   'weekends.',
#   'Christmas',
#   'the',
#   'this',
#   'your',
#   'behalf',
#   'grass.',
#   'an',
#   'one',
#   'his',
#   'TV',
#   'DVD.',
#   'your',
#   'a',
#   'a',
#   'this',
#   'fire?”',
#   'the',
#   'the',
#   'the',
#   'Broadway.',
#   'Broadway,',
#   'tour',
#   'our',
#   'those',
#   'your',
#   'stage,',
#   '57th',
#   '25th',
#   'that',
#   'me',
#   'Arsenio,',
#   'Bill',
#   'campus',
#   'the',
#   'MTV,',
#   'the',
#   'each',
#   'the',
#   'the',
#   'my',
#   'his',
#   'the',
#   'the',
#   'the',
#   'the',
#   'my'],
#  'August': ['7th,'],
#  '7th,': ['2037.'],
#  '2037.': ['That’s'],
#  'That’s': ['pretty',
#   'like,',
#   'not',
#   'not',
#   'not',
#   'not',
#   'your',
#   'so',
#   'how',
#   'insane.',
#   'the'],
#  'pretty': ['good.', 'rough'],
#  'good.': ['All', 'But', 'Let’s', 'But'],
#  'right.': ['Hello.', 'Real', 'Okay.', 'We', 'I'],
#  'Hello.': ['Hello,'],
#  'Hello,': ['Chicago.'],
#  'Chicago.': ['Nice', 'I', 'I'],
#  'Nice': ['to'],
#  'to': ['see',
#   'keep',
#   'go.',
#   'trace',
#   'write',
#   'you.”',
#   'Chicago.',
#   'it,',
#   'my',
#   'make',
#   'say.',
#   'watch',
#   'myself,',
#   'have',
#   'die.',
#   'a',
#   'an',
#   'milk',
#   'do',
#   'argue.',
#   'go',
#   'the',
#   'sit',
#   'your',
#   'go',
#   'the',
#   'have',
#   'come',
#   'do',
#   'the',
#   'the',
#   'see',
#   'the',
#   'her',
#   'the',
#   'the',
#   'go,',
#   'be',
#   'church',
#   'your',
#   'exclude',
#   'exclude',
#   '“And',
#   'trick',
#   'get',
#   'my',
#   'show',
#   'me.',
#   'eat',
#   'eat',
#   'convince',
#   'keep',
#   'deal',
#   'be',
#   'hang',
#   'see',
#   'budge.',
#   'have',
#   'make',
#   'make',
#   'lean',
#   'learn',
#   'start',
#   'his',
#   'say',
#   'say',
#   'talk',
#   'applaud',
#   'be',
#   'him',
#   'do',
#   'be',
#   'this',
#   'have',
#   'questions.',
#   'me',
#   'write',
#   'add',
#   'say?”',
#   'the',
#   'sell',
#   'be',
#   'go',
#   'be',
#   'be.',
#   'say.',
#   'fuck',
#   'rape',
#   'the',
#   'the',
#   'the',
#   'the',
#   'my',
#   'how',
#   'this',
#   'the',
#   'a',
#   'watch',
#   'be',
#   'Wisconsin.',
#   'be',
#   'talk',
#   'jail',
#   'battle',
#   'lose',
#   'Amazon.com.',
#   'find',
#   'people',
#   'the',
#   'try',
#   'preserve',
#   'afford',
#   'bother',
#   'single',
#   'see',
#   'office',
#   'retire',
#   'this',
#   'get',
#   'solve',
#   'me',
#   'her.',
#   'be',
#   'believe',
#   'be',
#   'keep',
#   'say',
#   'you',
#   'be',
#   'be',
#   'say,',
#   'prove',
#   'Mr.',
#   'be',
#   'them,',
#   'me.',
#   'me.',
#   'hear,',
#   'hear',
#   'hear',
#   'sell',
#   'perform',
#   'this.',
#   'pull?',
#   'nobody',
#   'cure',
#   'meet',
#   'meet',
#   'the',
#   'the',
#   'go.',
#   'meet',
#   'watch',
#   'school',
#   'see,',
#   'school',
#   'wait',
#   'walk',
#   'her',
#   'invite',
#   'go.',
#   'go',
#   'go.',
#   'kids’',
#   'play',
#   'reconnect',
#   'confront',
#   'kill',
#   'pass',
#   'meet',
#   'be',
#   'him',
#   'a',
#   '1997.',
#   'the',
#   'see',
#   'work',
#   'find',
#   'defend'],
#  'see': ['you',
#   'that',
#   'what',
#   'what',
#   'you',
#   'movies.',
#   'it.',
#   'where',
#   'that',
#   'a',
#   'the',
#   'Cirque',
#   'me',
#   'little',
#   'Bill.”',
#   'my'],
#  'you': ['again.',
#   'to',
#   'go',
#   'totally',
#   'just',
#   'could',
#   'could',
#   'point',
#   'sound',
#   'know?',
#   'feel',
#   'got',
#   'know.',
#   'should',
#   'can',
#   'can',
#   'don’t',
#   'know',
#   'marry',
#   'when',
#   'live',
#   'can’t',
#   'are.',
#   'have',
#   'have',
#   'the',
#   'guys',
#   'do',
#   'were',
#   'like',
#   'just',
#   'search',
#   'just',
#   'love',
#   'don’t',
#   'seen',
#   'can',
#   'know?',
#   'give',
#   'know',
#   'lie',
#   'that',
#   'talk.',
#   'having',
#   'should',
#   'cocksucker.',
#   'this.',
#   'or',
#   'need',
#   'don’t',
#   'not…',
#   'a',
#   'ever',
#   'know,',
#   'two.”',
#   'two',
#   'know.',
#   'know.',
#   'never',
#   'don’t',
#   'know,',
#   'should',
#   'have',
#   'know',
#   'for',
#   'know',
#   'and',
#   'have',
#   'think',
#   'to',
#   'for',
#   'know',
#   'raising',
#   'think,',
#   'know.',
#   'say,',
#   'get',
#   'get',
#   'came',
#   'were',
#   'know?',
#   'can’t',
#   'told',
#   'can',
#   'should',
#   'not,',
#   'know,',
#   'know,',
#   'know,',
#   'say',
#   'bite',
#   'three',
#   'will',
#   'see',
#   'have',
#   'won’t',
#   'lose',
#   'know?',
#   'and',
#   'look',
#   'were',
#   'doing?',
#   'watching',
#   'remember',
#   'wanted',
#   'know,',
#   'going',
#   'silly',
#   'do',
#   'do',
#   'out.',
#   'familiar',
#   'just',
#   'more',
#   'need,',
#   'to',
#   'need',
#   'was',
#   'just',
#   'hope?',
#   'see?',
#   'remember',
#   'were',
#   'know?',
#   'all',
#   'all',
#   'really',
#   'have',
#   'eat',
#   'can',
#   'did',
#   'were',
#   'one',
#   'know',
#   'that',
#   'know',
#   'seen',
#   'went',
#   'imagine',
#   'could',
#   'were',
#   'doctored',
#   'could',
#   'gonna',
#   'ball',
#   'push',
#   'start',
#   'talking',
#   'want',
#   'talk'],
#  'again.': ['Thank'],
#  'Thank': ['you.', 'you.', 'you.', 'you.'],
#  'you.': ['That', 'Look,', 'Some', 'I', 'And', 'What?', 'I', 'No', 'Mr.'],
#  'That': ['was',
#   'sounded',
#   'was',
#   'was',
#   'should',
#   'was',
#   'never',
#   'actually',
#   'if',
#   'was',
#   'was',
#   'sounds',
#   'was',
#   'morning,'],
#  'was': ['very',
#   'like,',
#   'like,',
#   'a',
#   'like,',
#   'sneaking',
#   'like,',
#   'like,',
#   'never',
#   'raised',
#   'the',
#   'an',
#   'just',
#   'a',
#   'treated',
#   'just',
#   'once',
#   'standing',
#   'coming',
#   'playing,',
#   'the',
#   'like,',
#   'going',
#   'batting,',
#   'the',
#   'the',
#   'like,',
#   'an',
#   'like,',
#   'never',
#   'like,',
#   'a',
#   'like,',
#   'built',
#   'flipped',
#   'like,',
#   'so',
#   'like',
#   'on',
#   'like,',
#   'like,',
#   'over',
#   'a',
#   'there.',
#   'bouncing',
#   'like,',
#   'like,',
#   'like,',
#   'a',
#   'a',
#   'gonna',
#   'a',
#   'a',
#   'better',
#   'near',
#   'like,',
#   'like,',
#   'like,',
#   'born',
#   'like,',
#   'like',
#   'driving,',
#   'a',
#   'a',
#   'how',
#   'arrested',
#   'just',
#   'a',
#   '12',
#   'like,',
#   'like',
#   'like,',
#   'an',
#   'there',
#   'in',
#   'trying',
#   'one',
#   'sitting',
#   'her',
#   'a',
#   'that',
#   'the',
#   'a',
#   'old,',
#   'Henry',
#   'in',
#   'a',
#   'in',
#   'in',
#   'Korean.',
#   'said',
#   'wearing',
#   'wearing',
#   'once',
#   'walking',
#   'alone',
#   'President',
#   'doing',
#   'like',
#   'not',
#   'the',
#   'the',
#   'Governor',
#   'first',
#   'first',
#   'invited',
#   'really',
#   'becoming',
#   'always',
#   'this',
#   'leaving',
#   'like,',
#   'like,',
#   'like,',
#   'like,',
#   'upstairs,',
#   'like,',
#   'ten',
#   'first',
#   'the',
#   '“Don’t',
#   'right',
#   'a',
#   'the',
#   'packed',
#   'packed',
#   'packed',
#   'there.',
#   'the',
#   'there.',
#   'him…',
#   'surrounded',
#   'swinging',
#   'just',
#   'like,',
#   'wearing',
#   'a',
#   'shitting',
#   'very',
#   'the',
#   'still',
#   '1992.\nLet’s',
#   'on'],
#  'very': ['nice.',
#   'friendly',
#   'friendly.',
#   'magical.',
#   'lucky',
#   'much.',
#   'lovely',
#   'interesting.',
#   'long',
#   'small.',
#   'weird',
#   'lazy.',
#   'good',
#   'good',
#   'upsetting',
#   'different',
#   'different',
#   'funny.'],
#  'nice.': ['Thank', 'I'],
#  'Look,': ['now,', 'it’s'],
#  'now,': ['you’re', 'it’s', 'but', 'and'],
#  'you’re': ['a',
#   'like,',
#   'very',
#   'gonna',
#   'like,',
#   'bad',
#   'gonna',
#   'never',
#   'supposed',
#   'a',
#   'doing?”',
#   'a',
#   'going',
#   'white.',
#   'a',
#   'like,',
#   'me.',
#   'so',
#   'Walter',
#   'my'],
#  'a': ['wonderful',
#   '“Happy',
#   'big-ass',
#   'big-ass',
#   'high',
#   'motorcycle',
#   'kind',
#   'fight',
#   'vibe',
#   'doll',
#   'while',
#   'person.',
#   'joke,',
#   'little',
#   'long',
#   'kid,',
#   'human',
#   'lot',
#   'lot',
#   'bananas',
#   'cow',
#   'situation.',
#   'problem',
#   'hundred',
#   'woman',
#   'really',
#   'family',
#   'lot',
#   'cow,',
#   'bossy',
#   'New',
#   'friend.',
#   'friend',
#   'beautiful',
#   'lot',
#   'hush',
#   'scandalous',
#   'French',
#   'period',
#   'variety',
#   'boring',
#   'wedding,',
#   'million',
#   'bunch',
#   'part',
#   'nice',
#   'little',
#   'little',
#   'sentence',
#   'dog.',
#   'little',
#   'tiny',
#   'puppy',
#   'bulldog,',
#   'baby',
#   'grandma.',
#   'river.',
#   'million',
#   'day.',
#   'dog',
#   'bad',
#   'dog.”',
#   'thing',
#   'foot',
#   'mighty',
#   'dog.”',
#   'play',
#   'wife',
#   'dog,',
#   'house.',
#   'new',
#   'lovely',
#   'house.',
#   'house,',
#   'real',
#   'paper',
#   'house,',
#   'house,',
#   'two-story',
#   'max',
#   'house.',
#   'real',
#   'real',
#   'big',
#   'baby',
#   'nursery.”',
#   'nursery.”',
#   'backyard',
#   'couple…',
#   'baby',
#   'run-in',
#   'two-year-old',
#   'sweet',
#   'lot.',
#   'very',
#   'penis.”',
#   'baby',
#   'penis”?',
#   'penis?”',
#   'baby,',
#   'penis,”',
#   'secret!”',
#   'lot.”',
#   'totally',
#   'grown',
#   'vagina,”',
#   '32-year-old',
#   'movie',
#   'kid.',
#   'thing.',
#   'little',
#   'lesbian.”',
#   'whole',
#   'little',
#   'test.',
#   'very',
#   'third',
#   'lot',
#   'little',
#   'supermarket',
#   'movie',
#   'very',
#   '17-year-old',
#   'disgraced',
#   'lazy',
#   'strange',
#   'family',
#   'guy',
#   'disgraced…',
#   'time',
#   'time',
#   'really',
#   'white',
#   'teacher.',
#   'super',
#   'vacation',
#   'resort,',
#   'question?”',
#   'rule.',
#   'rule',
#   'school',
#   'neon',
#   'glass',
#   'brother,',
#   'saucy',
#   "belt.'”",
#   'McDonald’s.',
#   'little',
#   'vanload',
#   'kid',
#   'five-year-old',
#   'kid',
#   'one-hitter',
#   'Rusted',
#   'very',
#   'really',
#   'law',
#   'little.',
#   'big',
#   'great',
#   'character',
#   'villainous',
#   'way',
#   'joint.',
#   'skull',
#   'Shakespeare',
#   'weed',
#   'certain',
#   'group',
#   'kid,',
#   'bra,',
#   'bra',
#   'while.',
#   'temp,',
#   'different',
#   'week.',
#   'couple',
#   'cubicle',
#   'conspiracy',
#   'week…',
#   'phone',
#   'week.',
#   'person',
#   'place',
#   'crossword',
#   'four-letter',
#   'little',
#   'small',
#   'rich',
#   'bow',
#   'hat,',
#   'cane',
#   'real',
#   'hard-boiled',
#   'raincoat,',
#   'rain',
#   'duck',
#   'duck,',
#   'duckling.',
#   '22-year-old',
#   'little',
#   'conversation',
#   'duck',
#   'duck,',
#   'new,',
#   'duckling!”',
#   'duck',
#   'duck',
#   'couple',
#   'duckling.',
#   'cigarette',
#   'dick',
#   'group.',
#   'dick',
#   'to-do',
#   'pretty',
#   'to-do',
#   'real',
#   'guy',
#   'smooth',
#   'show',
#   'college,',
#   'very',
#   'big,',
#   'little',
#   'couple',
#   'really',
#   'college',
#   'beer.”',
#   'much',
#   'fundraiser',
#   'kid',
#   'cool',
#   'big',
#   'homeless',
#   'spotlight,',
#   'little',
#   'human',
#   'snowplow.',
#   'bitch,',
#   'bunch',
#   'cartoon',
#   'quail',
#   'Democrat.”',
#   'chocolate',
#   'child.',
#   'sophomore',
#   'teenager'],
#  'wonderful': ['crowd,', 'thing'],
#  'crowd,': ['but', 'being'],
#  'but': ['I',
#   'the',
#   'you’re',
#   'still.',
#   'it',
#   'I',
#   'wouldn’t',
#   'they',
#   'it',
#   'it',
#   'I',
#   'also',
#   'you',
#   'I',
#   'you’re',
#   'also,',
#   'they',
#   'interesting',
#   'they',
#   'at',
#   'they'],
#  'I': ['need',
#   'don’t',
#   'know',
#   'have',
#   'mean,',
#   'don’t',
#   'walked',
#   'don’t',
#   'walk,',
#   'look',
#   'got',
#   'married',
#   'love',
#   'said',
#   'said,',
#   'was',
#   'was',
#   'shouldn’t',
#   'bet',
#   'never',
#   'like',
#   'got',
#   'don’t',
#   'was',
#   'used',
#   'would',
#   'got',
#   'was',
#   'totally',
#   'don’t',
#   'don’t',
#   'can’t',
#   'talked',
#   'got',
#   'heard',
#   'take',
#   'did',
#   'was',
#   'don’t',
#   'grew',
#   'saw',
#   'was',
#   'had',
#   'was',
#   'worked',
#   'know',
#   'grew',
#   'don’t',
#   'went',
#   'was',
#   'got',
#   'was',
#   'was',
#   'was',
#   'don’t',
#   'never',
#   'always',
#   'just',
#   'don’t',
#   'like',
#   'have',
#   'give',
#   'was',
#   'turned',
#   'was',
#   'once',
#   'reclaim',
#   'said,',
#   'do',
#   'was',
#   'will',
#   'eat',
#   'choose,',
#   'shit',
#   'give',
#   'have',
#   'pay',
#   'burst',
#   'was',
#   'like',
#   'loved',
#   'love',
#   'mean,',
#   'loved',
#   'know',
#   'think',
#   'can',
#   'know,',
#   'know,',
#   'was',
#   'think',
#   'got',
#   'was',
#   'went',
#   'didn’t',
#   'didn’t',
#   'just',
#   'don’t',
#   'like',
#   'don’t',
#   'had',
#   'know',
#   'really',
#   'really',
#   'was',
#   'was',
#   'thank',
#   'don’t',
#   'went',
#   'said,',
#   'don’t',
#   'thought',
#   'had',
#   'was',
#   'do,',
#   'go,',
#   'do,',
#   'do.',
#   'had',
#   'was',
#   'grew',
#   'did.',
#   'remember',
#   'don’t',
#   'was',
#   'thought.',
#   'was',
#   'lit',
#   'have',
#   'know',
#   'have',
#   'am',
#   'have',
#   'am',
#   'had',
#   'was',
#   'remember,',
#   'walked',
#   'walked',
#   'went,',
#   'turned',
#   'was.',
#   'rewatched',
#   'shit',
#   'think',
#   'see',
#   'mean,',
#   'have',
#   'don’t',
#   'would',
#   'had',
#   'was',
#   'remember,',
#   'did',
#   'went',
#   'was',
#   'was',
#   'was',
#   'would',
#   'have',
#   'could',
#   'would',
#   'would',
#   'would',
#   'would',
#   'remember,',
#   'have',
#   'have',
#   'was',
#   'was',
#   'did',
#   'think',
#   'got',
#   'agree,',
#   'don’t',
#   'more',
#   'get',
#   'don’t',
#   'hate',
#   'was',
#   'was',
#   'have',
#   'was',
#   'really',
#   'loved',
#   'would',
#   'worked',
#   'was',
#   'was',
#   'want',
#   'think',
#   'think',
#   'was',
#   'didn’t',
#   'need',
#   'temped',
#   'have',
#   'think',
#   'need',
#   'knew',
#   'don’t',
#   'think',
#   'mean,',
#   'don’t',
#   'did',
#   'knew',
#   'had',
#   'did',
#   'was',
#   'was',
#   'have',
#   'walked',
#   'walked',
#   'was',
#   'had',
#   'do',
#   'walk',
#   'like',
#   'like',
#   'just',
#   'wanna',
#   'get',
#   'met',
#   'don’t…',
#   'know',
#   'was',
#   'mentioned',
#   'can’t',
#   'don’t',
#   'met.',
#   'got',
#   'got',
#   'got',
#   'got',
#   'mean,',
#   'walk',
#   'walk',
#   'walk',
#   'walk',
#   'walk',
#   'wanted',
#   'was',
#   'was',
#   'slid',
#   'loved',
#   'was',
#   'learned',
#   'went',
#   'walk',
#   'walk',
#   'know',
#   'know',
#   'might',
#   'was',
#   'pushed',
#   'pushed',
#   'was',
#   'know',
#   'was',
#   'bought',
#   'thought',
#   'could',
#   'like',
#   'said,',
#   'got',
#   'got',
#   'went',
#   'went,',
#   'am',
#   'wake',
#   'am',
#   'open'],
#  'need': ['you', 'to', 'to', 'to', 'to', 'a', 'you', 'one.', 'to'],
#  'keep': ['your', 'that', 'my', 'a', 'looking'],
#  'your': ['energy',
#   'whole',
#   'milk.”',
#   'cow',
#   'cow',
#   'cow',
#   'name,',
#   'parents.',
#   'spirit.”',
#   'spirit.”',
#   'fucking',
#   'puppy.”',
#   'sovereign,',
#   'mom.',
#   'list.',
#   'Uncle',
#   'opinion.',
#   'hand',
#   'test,',
#   'brain',
#   'arm?”',
#   'law',
#   'car',
#   'car,',
#   'minivan',
#   'phone?',
#   'name?',
#   'own',
#   'favorite',
#   'research!',
#   'button.”'],
#  'energy': ['up', 'in'],
#  'up': ['the',
#   'in',
#   'is',
#   'Catholic,',
#   'Catholic.',
#   'in',
#   'at',
#   'and',
#   'the',
#   'before',
#   'to',
#   'with',
#   'on',
#   'in',
#   'a',
#   'and',
#   'for',
#   'strong',
#   'for',
#   'at',
#   'the',
#   'to',
#   'at',
#   'to'],
#  'the': ['entire',
#   'beginning',
#   'way,',
#   'second',
#   'hump',
#   '‘Y’,',
#   'lesson',
#   'past',
#   'past.',
#   'same',
#   'first',
#   'man',
#   'cow',
#   'milk',
#   'cow',
#   'milk',
#   'dairy',
#   'farmer',
#   'night.',
#   'cow?”',
#   'cow',
#   'cow,',
#   'cow',
#   'cow',
#   'cow?”',
#   'sale',
#   'sale,',
#   'entire',
#   'sale',
#   'one',
#   'sale.',
#   'cow?”',
#   'cow',
#   'most',
#   'third',
#   'cow,',
#   'side,',
#   'cow?',
#   'cow?',
#   'everything',
#   'elderly',
#   'wedding.',
#   'name',
#   'bishop?”',
#   'host',
#   'room.',
#   'bride',
#   'aisle,',
#   'organ',
#   'pews',
#   'bride',
#   'way',
#   'altar,',
#   'groom',
#   'veil',
#   'bride,',
#   'other',
#   'video',
#   'best',
#   'aisle,',
#   'organ’s',
#   'way',
#   'altar',
#   'world',
#   'eyes',
#   'videographer',
#   'church',
#   'middle',
#   'priest',
#   'one',
#   'priest',
#   'Catholic',
#   'squeaky',
#   'grease.',
#   'first',
#   'priest',
#   'first',
#   'Nazis',
#   'things',
#   'world.',
#   'apartment',
#   'trainer',
#   'apartment.',
#   'apartment,',
#   'threshold',
#   'problem',
#   'alpha',
#   'house.”',
#   'alpha',
#   'house.”',
#   'back',
#   'alpha',
#   'house.”',
#   'king',
#   'afternoon.',
#   'schedule',
#   'past',
#   '’20s,',
#   'bank',
#   'true',
#   'dumbest',
#   'world',
#   'biggest',
#   'downtown,',
#   'beach',
#   'way,',
#   'door.',
#   'house',
#   'Eagles',
#   'animosity',
#   'grass.”',
#   'movie',
#   'Fourth',
#   'baby',
#   'baby',
#   'baby',
#   'next',
#   'day.',
#   'day.',
#   'baby,',
#   'way,',
#   'baby',
#   'room,',
#   'baby',
#   'woman',
#   'penis',
#   'bottle',
#   'eggs',
#   'time…',
#   'Stamp',
#   'kind',
#   'biggest',
#   'roof.',
#   'double',
#   'woman',
#   'register',
#   'way',
#   'Future.',
#   'science',
#   'next',
#   'boy',
#   'scientist,',
#   'Kennedy',
#   'time',
#   'boy,',
#   'mom',
#   'son.',
#   'rapist',
#   'best',
#   'past.',
#   'Past?”',
#   'Future.”',
#   'past.”',
#   'parents',
#   'kids’',
#   'teacher',
#   'ear',
#   'only',
#   'first',
#   'resort,',
#   'man',
#   'resort',
#   'kitchen',
#   'cops,',
#   'movie',
#   'TV',
#   'room',
#   'TV',
#   'eyes',
#   'highway',
#   'side.',
#   'big',
#   'outside',
#   'highway.',
#   'road',
#   'distance,',
#   'golden',
#   'drive-thru,',
#   'funniest',
#   'entire',
#   'way,',
#   'first',
#   'government',
#   'Supreme',
#   'government',
#   'house',
#   'Bell,',
#   'episode',
#   'joint…',
#   'joint',
#   'joint',
#   'Chinese',
#   'Chinese',
#   'other',
#   'girls',
#   'relationship.',
#   'Chinese',
#   'letters',
#   'audience.',
#   'Cirque',
#   'crowd,',
#   'other',
#   'number',
#   'CEO',
#   'company',
#   '21st',
#   'office.',
#   'office,',
#   'way',
#   'realist',
#   'most',
#   'way,',
#   'wonderful',
#   'worst',
#   'end,',
#   'American',
#   'way.',
#   'night',
#   'United',
#   'United',
#   'name,',
#   'hell',
#   'appetites.”',
#   'world',
#   'Bill',
#   'saxophone',
#   'STD',
#   'man',
#   'Bill',
#   'same',
#   'same',
#   'president.',
#   'people',
#   'president.',
#   'president.',
#   '1990s',
#   'library',
#   'library',
#   'library,',
#   'other',
#   'room',
#   'most',
#   'piano.',
#   'ballroom.',
#   'Palmer',
#   'ballroom,',
#   'ballroom',
#   'end',
#   'movie',
#   'end',
#   'one-armed',
#   'target.',
#   'ballroom',
#   'samples!”',
#   'way?',
#   'samples!',
#   'local',
#   'soup?”',
#   'far',
#   'ballroom,',
#   'back',
#   'next',
#   'United',
#   'ground.',
#   'reporters,',
#   'photographers.',
#   'Secret',
#   'hell',
#   'fundraiser.',
#   'best',
#   'moral',
#   'end',
#   'morning',
#   'Monica',
#   'cover',
#   'Drudge',
#   'cover',
#   'newspaper',
#   'face.',
#   'newspaper',
#   'face'],
#  'entire': ['show,', 'gender.', 'time', 'one', 'life.', 'time?”', 'life.'],
#  'show,': ['okay?'],
#  'okay?': ['Because…', 'We’ve'],
#  'Because…': ['No,'],
#  'No,': ['no,',
#   'really.',
#   'being',
#   'I',
#   'like',
#   'I’m',
#   'this',
#   'he',
#   'my',
#   'no.'],
#  'no,': ['no.', 'no.', 'good', 'no.'],
#  'no.': ['Thank', 'I', 'No,', 'Back', 'But,'],
#  'Some': ['crowds…', 'people', 'Dutch', 'of'],
#  'crowds…': ['some'],
#  'some': ['crowds,',
#   'kick-ass',
#   'village?',
#   'old',
#   'boring',
#   'Cheeto-fingered,',
#   'sound',
#   'guy',
#   'grass',
#   'of',
#   'form',
#   'weed',
#   'of',
#   'of'],
#  'crowds,': ['they', 'by'],
#  'they': ['have',
#   'run',
#   'were',
#   'buy',
#   'looked,',
#   'were',
#   'introduced',
#   'changed',
#   'were',
#   'changed',
#   'weren’t',
#   'were',
#   'wrote,',
#   'didn’t',
#   'are',
#   'have',
#   'all',
#   'were',
#   'have',
#   'never',
#   'became',
#   'go',
#   'build',
#   'go',
#   'stop',
#   'do',
#   'go',
#   'go',
#   'trusted',
#   'shouldn’t',
#   'were',
#   'scared',
#   'scared',
#   'had',
#   'pulled',
#   'brought',
#   'reached',
#   'were',
#   'had',
#   'pulled',
#   'were',
#   'just',
#   'say',
#   'mean',
#   'legalize',
#   'kind',
#   'knew',
#   'only',
#   'went',
#   'went',
#   'had',
#   'were'],
#  'have': ['big',
#   'no',
#   'said',
#   'you.”',
#   'an',
#   'ended',
#   'a',
#   'them',
#   'to',
#   'to',
#   'the',
#   'been',
#   'some.”',
#   'any',
#   'a',
#   'a',
#   'seen,',
#   'no',
#   'to',
#   'to',
#   'a',
#   'a',
#   'to',
#   'various',
#   'kind',
#   'little',
#   'a',
#   'a',
#   'a',
#   '’em,',
#   'some',
#   'a',
#   'babies',
#   'a',
#   'no',
#   'to',
#   'answers',
#   'had',
#   'no',
#   'a',
#   'gone',
#   'this',
#   'ever',
#   'it',
#   'taken',
#   'trusted',
#   'a',
#   'your',
#   'all',
#   'responsibilities',
#   'two',
#   'ever',
#   'to',
#   'had',
#   'been',
#   'no',
#   'unlimited',
#   'unlimited',
#   'my',
#   'your',
#   'the',
#   'all',
#   'to',
#   'to',
#   'cool',
#   'Provasic!”',
#   'the'],
#  'big': ['energy',
#   'too',
#   'letters',
#   'chair.',
#   'family-action-comedy.',
#   'announcement.',
#   'deal',
#   'hotel',
#   'Hilton'],
#  'in': ['the',
#   'the',
#   'Chicago.',
#   'a',
#   'my',
#   'relationships',
#   'a',
#   'that',
#   'the',
#   'some',
#   'at',
#   'a',
#   'a',
#   'cows',
#   'my',
#   'this',
#   'Chicago',
#   'the',
#   'church',
#   'the',
#   'the',
#   'the',
#   'the',
#   'front',
#   'a',
#   'the',
#   '2014.',
#   'July',
#   'the',
#   'the',
#   'a',
#   'the',
#   'our',
#   'our',
#   'case',
#   'the',
#   'their',
#   'its',
#   'and',
#   'that',
#   'and',
#   'the',
#   'elementary',
#   'college.',
#   'elementary',
#   'my',
#   'my',
#   'through',
#   'a',
#   'the',
#   'and',
#   'time',
#   'time,',
#   'time',
#   'and',
#   'front',
#   'my',
#   'the',
#   'advance,',
#   'that',
#   'the',
#   'that',
#   'our',
#   'the',
#   'the',
#   'our',
#   'our',
#   'the',
#   'retrospect,',
#   'my',
#   '18',
#   'some',
#   'the',
#   'the',
#   'its',
#   'a',
#   'a',
#   'a',
#   'on',
#   'New',
#   'a',
#   'the',
#   'her',
#   'New',
#   'molasses',
#   'a',
#   'the',
#   'his',
#   'her',
#   'front',
#   'and',
#   'all',
#   'front',
#   'all',
#   'New',
#   'front',
#   'a',
#   'all',
#   'the',
#   'curing',
#   '1992,',
#   'the',
#   'front',
#   'front',
#   'college',
#   'the',
#   'my',
#   'to',
#   'high',
#   'his',
#   'the',
#   'bed,',
#   'the',
#   'to'],
#  'beginning': ['and'],
#  'and': ['then',
#   'then',
#   'you’re',
#   'then',
#   'cursive',
#   'you',
#   'I’ll',
#   'vulnerable.',
#   'we',
#   'Anna’s',
#   'my',
#   'I',
#   'I',
#   'met',
#   'you',
#   'your',
#   'cow',
#   'getting',
#   'if',
#   'then',
#   'then',
#   'he',
#   'the',
#   'all',
#   'the',
#   'the',
#   'right',
#   'they',
#   'she’s',
#   'the',
#   'he',
#   'to',
#   'I',
#   'I',
#   'I',
#   'barks',
#   'bites',
#   'went,',
#   'two',
#   'what',
#   'tremble.',
#   'I',
#   'I',
#   'spoons,',
#   'in',
#   'a',
#   'we',
#   'I’m',
#   'pants',
#   'she',
#   'Stacia',
#   'nine',
#   'a',
#   'then,',
#   'then…',
#   'catfishing',
#   'I',
#   'a',
#   'go…',
#   'go,',
#   'I',
#   'I',
#   'he',
#   'down,',
#   'he',
#   'he',
#   'said,',
#   'knowingly',
#   'I',
#   'she',
#   'I',
#   'she',
#   'she',
#   'vagina',
#   'the',
#   'it’s',
#   'upsets',
#   'angry',
#   'I',
#   'being',
#   'you',
#   'that’s',
#   'you',
#   'I',
#   'the',
#   'she',
#   'left.',
#   'do',
#   'he’s',
#   'the',
#   'they',
#   'they',
#   'they',
#   'he',
#   'teachers.',
#   'been',
#   'they',
#   'he',
#   'I’ve',
#   'I',
#   'I',
#   'Al',
#   'I.',
#   'me,',
#   'grab',
#   'pretend',
#   'he',
#   'go,',
#   'a',
#   'all',
#   'thought,',
#   'we',
#   'he',
#   'there',
#   'said,',
#   'healthcare,',
#   'be',
#   'we',
#   'they’re',
#   'the',
#   'that',
#   'then',
#   'my',
#   'he',
#   'I',
#   'they',
#   'they',
#   'they',
#   'they',
#   'be',
#   'I',
#   'this',
#   'I’m',
#   'she',
#   'small',
#   'he',
#   'he',
#   'he',
#   'I’m',
#   'you’re',
#   'you',
#   'I',
#   'he',
#   'mortality…',
#   'been',
#   '31st.',
#   'down,',
#   'could',
#   'she',
#   'I’m',
#   'sell',
#   'sell',
#   'been',
#   'done?',
#   'suck',
#   'then',
#   'you',
#   'he',
#   'fantastic',
#   'I',
#   'he',
#   'he’s',
#   'his',
#   'everyone',
#   'offer',
#   'Bill',
#   'she',
#   'I’ll',
#   'he’d',
#   'for',
#   'I',
#   'I',
#   'Lentz,',
#   'he',
#   'gentlemen,',
#   'photographers,',
#   'Secret',
#   'you',
#   'says,',
#   'she',
#   'he’s',
#   'it',
#   'it',
#   'he',
#   'my',
#   'I',
#   'then',
#   'the',
#   'falls',
#   'he'],
#  'then': ['they',
#   'run',
#   'we’ll',
#   'you',
#   'I',
#   'on',
#   'you’d',
#   'they',
#   'I',
#   'in',
#   'change',
#   'she',
#   'walk',
#   'the',
#   'it',
#   'the',
#   'I',
#   'the',
#   'suddenly',
#   'it',
#   'you',
#   'she',
#   'to',
#   'Mary',
#   'walked',
#   'that',
#   'they',
#   'you',
#   'it',
#   'my'],
#  'run': ['out', 'out'],
#  'of': ['places',
#   'room.',
#   'that',
#   'like',
#   'curled-up',
#   'course.',
#   'information.',
#   'people',
#   'purchase.”',
#   'them',
#   'estimates,',
#   'people',
#   'you.',
#   'the',
#   'MTV’s',
#   'Catholic',
#   'time.',
#   'sirs.”',
#   'the',
#   'this',
#   'God.',
#   'new',
#   'Mass,',
#   'you',
#   'makes',
#   'like,',
#   'the',
#   'the',
#   'my',
#   'the',
#   'alpha,',
#   'a',
#   'her,',
#   '2029.”',
#   'their',
#   'HGTV',
#   '$7…',
#   'You',
#   'fun',
#   'life',
#   'my',
#   'July,',
#   'a',
#   'these',
#   'eggs,',
#   '1775',
#   'my',
#   'stress',
#   'those',
#   'rights.',
#   'children',
#   'that.”',
#   'the',
#   'her.',
#   'them.',
#   'had',
#   'Pepsi.',
#   'us',
#   'wood?',
#   'wood',
#   'your',
#   'little',
#   'politeness',
#   'the',
#   'math.',
#   'the',
#   'French',
#   'her',
#   'a',
#   'my',
#   'a',
#   'business.',
#   'the',
#   'dice',
#   'me',
#   'you,',
#   'scanning',
#   'data,',
#   'her',
#   'things',
#   'here,',
#   'you',
#   'you',
#   'the',
#   'the',
#   'America.',
#   'didn’t',
#   'the',
#   'chivalrous',
#   'the',
#   'guy.',
#   'the',
#   'this,',
#   'course,',
#   'Chicago',
#   'the',
#   'silver',
#   'my',
#   'the',
#   'implying',
#   'stuff',
#   'George',
#   'my',
#   'a',
#   'that',
#   'The',
#   'The'],
#  'places': ['to'],
#  'go.': ['So…', 'Now,', 'We', '‘Cause'],
#  'So…': ['I', 'we', 'for', 'eggs.”', 'This', 'she'],
#  'don’t': ['judge',
#   'need',
#   'like',
#   'give',
#   'know',
#   'mean',
#   'care',
#   'own.',
#   'wanna',
#   'know',
#   'go',
#   'mean',
#   'have',
#   'actually',
#   'know',
#   'know',
#   'know',
#   'even',
#   'want',
#   'think',
#   'care',
#   'do',
#   'know',
#   'know.',
#   'think',
#   'know,”',
#   'know.',
#   'know.”',
#   'know.',
#   'even',
#   'know',
#   'know.',
#   'mean',
#   '“whoo”',
#   'go',
#   'just',
#   'show',
#   'let',
#   'look',
#   'give',
#   'mean',
#   'know',
#   'know,',
#   'you',
#   'have',
#   'know,'],
#  'judge': ['those'],
#  'those': ['crowds,',
#   'times',
#   'guys',
#   'of',
#   'true',
#   'times',
#   'dumplings?”',
#   'of'],
#  'by': ['the',
#   'a',
#   'a',
#   'a',
#   'month',
#   'the',
#   'myself,',
#   'the',
#   'the',
#   'the',
#   'humiliating',
#   'one.',
#   'then',
#   'this',
#   'the',
#   'the',
#   'the',
#   'Fleetwood',
#   'and',
#   'the',
#   'reporters,'],
#  'way,': ['okay?', 'but', 'and', 'it', 'like,', 'I', 'that'],
#  'We’ve': ['all', 'all', 'been'],
#  'all': ['gone',
#   'made',
#   'right.',
#   'violent',
#   'those',
#   'the',
#   'the',
#   'the',
#   'said…',
#   'day',
#   'of',
#   'right.',
#   'pavement.',
#   'did.',
#   'be',
#   'the',
#   'fine',
#   'right,',
#   'right,',
#   'right.',
#   'these',
#   'four',
#   'those',
#   'friends.”',
#   'this',
#   'this',
#   'imagine.',
#   'had',
#   'got',
#   'that',
#   'sincerity.',
#   'thin',
#   'signed',
#   'elected',
#   'these',
#   'know',
#   'know',
#   'of',
#   'the',
#   'the',
#   'the'],
#  'gone': ['too', 'through', 'into', 'to'],
#  'too': ['big', 'fast', 'young', 'old'],
#  'fast': ['and'],
#  'room.': ['We’ve', 'Isn’t'],
#  'made': ['a', 'it', 'of', 'me'],
#  '“Happy': ['Birthday”'],
#  'Birthday”': ['sign…'],
#  'sign…': ['Wait.'],
#  'Wait.': ['You'],
#  'get': ['that',
#   'it.”',
#   'married.',
#   'the',
#   'the',
#   'a',
#   'him',
#   'an',
#   'it',
#   'to,',
#   'to.',
#   'me',
#   'along.',
#   'away',
#   'on',
#   'in',
#   'pulled',
#   'to',
#   'the',
#   'better',
#   'out'],
#  'that': ['poster',
#   'first',
#   'from',
#   'vibe.',
#   'you',
#   'is',
#   'way,',
#   'fella?',
#   'way',
#   'before?',
#   'you',
#   'a',
#   'happening',
#   'expression',
#   'question',
#   'knows',
#   'wanted',
#   'farmer',
#   'you',
#   'you',
#   'anymore.',
#   'from',
#   'alienates',
#   'became',
#   'moment',
#   'wedding',
#   'second,',
#   'aren’t',
#   'needed',
#   'clunky.',
#   'for',
#   'is',
#   'every',
#   'was',
#   'existed',
#   'you’ve',
#   'they',
#   'hard',
#   'was',
#   'shit',
#   'story,',
#   'is?',
#   'day!',
#   'situation.',
#   'day.',
#   'phase',
#   'movie',
#   'just',
#   'when',
#   'the',
#   'I',
#   'a',
#   'away',
#   'the',
#   'you',
#   'he',
#   'way',
#   'scene',
#   'diner.',
#   'rapport',
#   'way.”',
#   'era?',
#   'made',
#   'is',
#   'no',
#   'is',
#   'we',
#   'same',
#   'are',
#   'two',
#   'it',
#   'afternoon.',
#   'every',
#   'happens',
#   'a',
#   'conversation',
#   'point,',
#   'moment,',
#   'it',
#   'time',
#   'they',
#   'is',
#   'afternoon.',
#   'that',
#   'list',
#   'the',
#   'to',
#   'in',
#   'is?',
#   'don’t,',
#   'we',
#   'time.',
#   'I',
#   'is',
#   'there',
#   'Bill',
#   'he',
#   'Bill',
#   'ballroom.',
#   'ballroom.',
#   'Nichols,',
#   'guy',
#   'you',
#   'ballroom.',
#   'ballroom.',
#   'I',
#   'she',
#   'I’m',
#   'I',
#   'only',
#   'night…',
#   'night,',
#   'story.',
#   'the',
#   'his'],
#  'poster': ['board'],
#  'board': ['up,', 'with'],
#  'up,': ['and', 'and'],
#  'like,': ['“I',
#   '“Yeah,',
#   '“Do',
#   '“Hey,',
#   '“Yes,',
#   '“Oh,',
#   '‘Can',
#   '“Ooh,',
#   'long',
#   '“Oh,',
#   '“No',
#   '“Ah-ha-ha,',
#   '“Well,',
#   '“No,',
#   '“Why',
#   'eight',
#   '“John',
#   '“Hey,',
#   '“Aw,',
#   '“I',
#   '.400.',
#   '“Let’s',
#   '“How',
#   '“Nothing',
#   'they',
#   '“Hey,',
#   '“Oh,',
#   '“I',
#   '“Let’s',
#   '“Petunia',
#   '“2029?',
#   '“Craig',
#   'two',
#   'the',
#   '“Hi,',
#   '“Jesus',
#   '“So,',
#   '“Oh,',
#   '“Hey,',
#   'stroller',
#   'working',
#   '“Oh,',
#   '“Do',
#   '“Yes,',
#   '“It’s',
#   '“She',
#   '“Yes,',
#   '“Hooray!',
#   '“Sometimes,',
#   '“Hey,',
#   '“Well,',
#   '“I',
#   '“Partial',
#   '“Hey,',
#   '“Hey,',
#   '“What,',
#   '“Okay…',
#   '40',
#   '“Excuse',
#   '“John',
#   '“Hey,',
#   '“My',
#   '“Oh,',
#   '“Oh,',
#   '“So,',
#   '“Well,',
#   '“Nah.”',
#   'they',
#   'cops',
#   '“Hmm,',
#   'a',
#   '“How',
#   '“Fine.”',
#   '“Gay',
#   '“We’ll',
#   '“Excuse',
#   '“Okay,',
#   '“Hey,',
#   '“Yeah,',
#   '“No',
#   '“Le',
#   '“No!”',
#   '“That’s',
#   '“Thank',
#   '“Goodbye!”',
#   '“Hey,',
#   '“Mischa,',
#   '“Remember,',
#   '“Hey,',
#   '‘Too',
#   '“Ah,',
#   '“Little',
#   '“What',
#   '“But',
#   'they',
#   '“Hey,',
#   'alumni',
#   '“Hey,',
#   '“Hey,',
#   '“Hell,',
#   '“You',
#   '“Thanks,',
#   '“Hell,',
#   '“Governor,',
#   '“I',
#   '“Yay,',
#   '“Ladies',
#   '“Oh,',
#   '“Man,',
#   '“What',
#   'reading'],
#  '“I': ['don’t',
#   'didn’t',
#   'was',
#   'got',
#   'see',
#   'was',
#   'don’t',
#   'think',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'don’t',
#   'guess',
#   'don’t'],
#  'trace': ['it.'],
#  'it.': ['I',
#   'And…',
#   'When',
#   '‘Cause',
#   'Like,',
#   'So…',
#   'Great',
#   'Not',
#   'We',
#   'It’d',
#   '‘Cause',
#   'I'],
#  'know': ['how',
#   'if',
#   'how',
#   'what',
#   'what',
#   'if',
#   'that’s',
#   'how',
#   'that',
#   'if',
#   'if',
#   'what’s',
#   'there',
#   'who',
#   'what',
#   'what',
#   'my',
#   'how',
#   'you',
#   'how',
#   'why…',
#   'her',
#   'why',
#   'who',
#   'you',
#   'who',
#   'who',
#   'who',
#   'we',
#   'this,',
#   'we',
#   'this.',
#   'now'],
#  'how': ['big',
#   'kids',
#   'to',
#   'that',
#   'you',
#   'you',
#   'can',
#   'all',
#   'I’m',
#   'life',
#   'broken',
#   'they',
#   'old',
#   'I',
#   'much',
#   'many',
#   'he',
#   'you'],
#  'letters': ['should', 'and', 'will', 'of'],
#  'should': ['be.',
#   'get',
#   'have',
#   'have',
#   'start',
#   'be',
#   'be',
#   'be',
#   'be',
#   'I',
#   'be'],
#  'be.': ['To', 'But'],
#  'To': ['begin', 'which'],
#  'begin': ['with,', 'a'],
#  'with,': ['a'],
#  'big-ass': ['‘H’.', '‘A’'],
#  '‘H’.': ['Followed'],
#  'Followed': ['by'],
#  '‘A’': ['and…'],
#  'and…': ['Oh,', 'a'],
#  'Oh,': ['no!', 'God!', 'yes,', 'wow,'],
#  'no!': ['Oh,'],
#  'God!': ['Okay,'],
#  'Okay,': ['all'],
#  'Real': ['skinny', 'estate'],
#  'skinny': ['‘P’'],
#  '‘P’': ['with', 'below'],
#  'with': ['a',
#   '“Happy.”',
#   'me.”',
#   'me?”',
#   'you?”',
#   'what',
#   'the',
#   'another',
#   'my',
#   'you.”',
#   'your',
#   'you.',
#   'you.”',
#   'you.”',
#   'your',
#   'you.”',
#   'you.”',
#   '“And',
#   "you.'”",
#   'her',
#   'President',
#   'the',
#   'her.',
#   'my',
#   'Bobby',
#   'them.',
#   'a',
#   'that',
#   'that,',
#   'rage?',
#   'it.',
#   'the',
#   'only',
#   'criminals.',
#   'breaking',
#   'wood',
#   'a',
#   'weed,',
#   'some',
#   'the',
#   'an',
#   'my',
#   'this',
#   'just',
#   'Bill',
#   'become',
#   'Bill',
#   'Bill',
#   'anything.”',
#   'my',
#   'Governor',
#   'people.',
#   'people,',
#   'people.',
#   'Devlin',
#   'people.',
#   'people.'],
#  'high': ['hump,', 'school', 'school,'],
#  'hump,': ['and'],
#  'we’ll': ['put'],
#  'put': ['the', 'this', 'a'],
#  'second': ['‘P’', 'term'],
#  'below': ['the'],
#  'hump': ['of'],
#  'first': ['‘P’,',
#   'moment',
#   'church',
#   'time',
#   'place?',
#   'time',
#   'days,',
#   'running',
#   'running',
#   'and',
#   'released,'],
#  '‘P’,': ['sort'],
#  'sort': ['of', 'of', 'of'],
#  'like': ['a',
#   'confrontation,',
#   'this.',
#   'a',
#   'a',
#   'to',
#   'anymore.',
#   'bulls,',
#   'saying,',
#   'if',
#   'having',
#   'having',
#   'me,',
#   'having',
#   'hanging',
#   'your',
#   'we',
#   'this',
#   'we',
#   'that.',
#   'me',
#   'to',
#   'her.',
#   'his',
#   'the',
#   'Ferris',
#   'us.',
#   'that',
#   'a',
#   'cool',
#   '“Ah,',
#   'Lou',
#   'she',
#   'a',
#   'a',
#   'a',
#   'a',
#   'a',
#   'that.',
#   'me.”',
#   'I',
#   'structure,',
#   'a',
#   'a',
#   'Frank',
#   'he’s',
#   'a',
#   'a',
#   'your'],
#  'motorcycle': ['sidecar'],
#  'sidecar': ['situation.'],
#  'situation.': ['And', 'Was', 'Here’s'],
#  'And': ['now',
#   'then',
#   'I',
#   'they',
#   'I',
#   'I',
#   'then',
#   'I',
#   'I',
#   'the',
#   'he',
#   'he',
#   'also,',
#   'the',
#   'does',
#   'she’s',
#   'if',
#   'you',
#   'a',
#   'the',
#   'then',
#   'I',
#   'she',
#   'right',
#   'then',
#   'then',
#   'everyone',
#   'I',
#   'for',
#   'you’re',
#   'it',
#   'they',
#   'also',
#   'then',
#   'then',
#   'in',
#   'she',
#   'I',
#   'they',
#   'they’re',
#   'I',
#   'these',
#   'I',
#   'that’s',
#   'it’ll',
#   'then',
#   'it',
#   'he',
#   'I',
#   'then',
#   'I',
#   'then',
#   'we',
#   'what',
#   'they’re',
#   'that’s',
#   'if',
#   'I',
#   'I',
#   'I',
#   'there',
#   'we',
#   'also,',
#   'my',
#   'I',
#   'we',
#   'then',
#   'he',
#   'I',
#   'we',
#   'I',
#   'I’d',
#   'I’d',
#   'the',
#   'I',
#   'in',
#   'we',
#   'my',
#   'then,',
#   'kept',
#   'my',
#   'I’ve',
#   'they’re',
#   'then',
#   'that’s',
#   'then,',
#   'they’d',
#   'now',
#   'I',
#   'we',
#   'we',
#   'we',
#   'we’re',
#   'these',
#   'they',
#   'they',
#   'they',
#   'everyone',
#   'my',
#   'then',
#   'they’re',
#   'her',
#   'then',
#   'I',
#   'he',
#   'when',
#   'then',
#   'then',
#   'then',
#   'I',
#   'to',
#   'I',
#   'she',
#   'I',
#   'isn’t',
#   'he’s',
#   'that',
#   'my',
#   'my',
#   'one',
#   'my',
#   'she',
#   'I',
#   'also,',
#   'without',
#   'I',
#   'I',
#   'he',
#   'he’d',
#   'we’d',
#   'he',
#   'Dr.',
#   'you',
#   'he’d',
#   'they’d',
#   'on',
#   'it',
#   'then',
#   'I',
#   'I',
#   'he',
#   'it',
#   'I',
#   'Bill',
#   'I',
#   'he',
#   'I',
#   'I',
#   'without',
#   'on',
#   'I',
#   'then'],
#  'now': ['I', 'and', 'I’m', 'like,', 'it’s', 'that', '1997.'],
#  'no': ['room',
#   'sense.',
#   'proof',
#   'reason',
#   'idea.',
#   'longer',
#   'toilets.',
#   'one',
#   'supervision',
#   'one',
#   'outlet',
#   'money.',
#   'rights',
#   'child',
#   'one',
#   'idea',
#   'more.”',
#   'plan.'],
#  'room': ['for', 'she', 'and', 'in'],
#  'for': ['the',
#   'real,',
#   'free?”',
#   'free?”',
#   'real,',
#   'a',
#   'a',
#   'no',
#   'many,',
#   '2,000',
#   'the',
#   'the',
#   '30',
#   '30',
#   'instance,',
#   'a',
#   'a',
#   'you.”',
#   'that',
#   'the',
#   'laughing,',
#   'some',
#   'asking.',
#   'it.',
#   'kids',
#   'the',
#   'people.',
#   'a',
#   'three',
#   'all',
#   'three',
#   'himself.',
#   'us.',
#   'marijuana,',
#   '40',
#   'weed',
#   'a',
#   'a',
#   'a',
#   '‘be',
#   'you.',
#   'an',
#   'coming',
#   '20',
#   'president.\nAnd',
#   'president,',
#   'a',
#   'a',
#   'a',
#   'people',
#   'Bill',
#   'work,'],
#  '‘Y’,': ['so'],
#  'so': ['I’ll',
#   'open',
#   'adult.',
#   'much',
#   'nice.',
#   'you',
#   'we',
#   'he',
#   'fun',
#   'well',
#   'sweet.',
#   'discretion',
#   'that',
#   'horny',
#   'that',
#   'bad!”',
#   'different,',
#   'excited.',
#   'hungover,',
#   'she',
#   'it’s',
#   'that'],
#  'I’ll': ['do', 'probably', 'be', 'be', 'kill', 'say', 'go', 'take'],
#  'do': ['a',
#   'it,',
#   'with',
#   'have.',
#   'on',
#   'I',
#   'that?”',
#   'on',
#   'tell.”',
#   'so',
#   'you',
#   'what',
#   'you',
#   'that.',
#   'that.',
#   'they',
#   'with',
#   'it',
#   'you',
#   'to',
#   'with',
#   'nothing',
#   'fun',
#   'whatever'],
#  'kind': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'curled-up': ['noodle'],
#  'noodle': ['‘Y’.'],
#  '‘Y’.': ['Block'],
#  'Block': ['letters'],
#  'cursive': ['look'],
#  'look': ['good', 'like', 'of', 'like', 'up', 'at', 'my', 'the', 'at'],
#  'good': ['together.”', 'dinner.”', 'idea,', 'point.', 'now.', 'thing.'],
#  'together.”': ['And'],
#  'go': ['to',
#   'out',
#   'to',
#   'to',
#   'to',
#   'into',
#   'in.”',
#   'see',
#   'in',
#   'back',
#   'back',
#   'to',
#   'to',
#   'to',
#   'somewhere',
#   'from',
#   'see',
#   'and',
#   'on',
#   'undercover'],
#  'write': ['“Birthday”', 'in,'],
#  '“Birthday”': ['and'],
#  'totally': ['forget', 'get', 'different', 'unprompted.'],
#  'forget': ['the'],
#  'lesson': ['you'],
#  'just': ['learned',
#   'dating,',
#   'has',
#   'a',
#   'creepy',
#   'bought…',
#   'bought',
#   'some',
#   'a',
#   'a',
#   'a',
#   'immediately',
#   'wanna',
#   'have',
#   'staring',
#   'bought',
#   'some',
#   'don’t',
#   'made',
#   'going',
#   'blowing',
#   'meant',
#   'your',
#   'matters',
#   'looked',
#   'go',
#   'like,',
#   'didn’t',
#   'been',
#   'reading',
#   'didn’t',
#   'like,',
#   'something',
#   'like,',
#   'mean',
#   'go',
#   'get',
#   'wanna',
#   'about',
#   'be',
#   'have',
#   'about',
#   'wanna',
#   'an',
#   'being',
#   'says,',
#   'mowing',
#   'like…',
#   'said,',
#   'dropped.”'],
#  'learned': ['with', 'to'],
#  '“Happy.”': ['You’re'],
#  'You’re': ['like,', 'very', 'not', 'very', 'like,', 'a'],
#  '“Yeah,': ['but', 'we’re'],
#  'past': ['is', 'month,', 'her,', 'her', 'all', 'all', 'all'],
#  'is': ['the',
#   'more',
#   'so',
#   'gonna',
#   'so',
#   'an',
#   'your',
#   'way',
#   'like,',
#   'Jewish.',
#   'Jewish,',
#   'a',
#   'the',
#   'also',
#   'young,',
#   'as',
#   'my',
#   'a',
#   'what',
#   'like,',
#   'nowhere',
#   'the',
#   'an',
#   'what',
#   'key.”',
#   'just',
#   'a',
#   'a',
#   'another',
#   'the',
#   'she',
#   'the',
#   'that?',
#   'cold-blooded.',
#   'legal',
#   'the',
#   'just',
#   'great',
#   'terrible',
#   'happy!”',
#   'happy!”',
#   'life',
#   'not',
#   'a',
#   'he',
#   'not',
#   'super',
#   'absolutely',
#   'like,',
#   'the',
#   'revealed',
#   'my',
#   'about',
#   'now',
#   'in'],
#  'past.': ['Big-ass', 'How'],
#  'Big-ass': ['‘B’.'],
#  '‘B’.': ['Surely'],
#  'Surely': ['more'],
#  'more': ['letters',
#   'like,',
#   'than',
#   'than',
#   'supervised',
#   'than',
#   'feel',
#   'description',
#   'story',
#   'morally-upright,'],
#  'fit': ['in'],
#  'same': ['space.”', 'politeness', 'college', 'college.'],
#  'space.”': ['You’re'],
#  'friendly': ['here'],
#  'here': ['in', 'at'],
#  'mean,': ['we’re', 'they', 'we', 'imagine', 'think'],
#  'we’re': ['all',
#   'space',
#   'eating',
#   'gonna',
#   'gonna',
#   'gonna',
#   'going',
#   'gonna',
#   'not',
#   'going',
#   'hanging',
#   'like,',
#   'all'],
#  'violent': ['here,', 'video'],
#  'here,': ['but', 'by', 'about'],
#  'friendly.': ['No,'],
#  'really.': ['And'],
#  'confrontation,': ['’cause'],
#  '’cause': ['I’ve',
#   'you',
#   'it’s',
#   'she’s',
#   'I',
#   'I',
#   'it',
#   'your',
#   'they’re',
#   'I',
#   'think',
#   'Bill',
#   'he'],
#  'I’ve': ['never', 'been', 'never', 'seen', 'just', 'been', 'ever', 'never'],
#  'never': ['been',
#   'knew',
#   'anything',
#   'liked',
#   'the',
#   'know.',
#   'too',
#   'been',
#   'been',
#   'explain',
#   'explain',
#   'happened.',
#   'seen',
#   'like,',
#   'seen',
#   'forgets',
#   'gonna'],
#  'been': ['in',
#   'a',
#   'home',
#   'in',
#   'in',
#   'about',
#   'like,',
#   'a',
#   'like,',
#   'supervised',
#   'smaller.',
#   'like,',
#   'informed',
#   'on',
#   'on',
#   'legal',
#   'talking',
#   'raining.',
#   'like,',
#   'like,',
#   'a',
#   'on',
#   'hired'],
#  'fight': ['before.'],
#  'before.': ['Though,', 'I’m', 'Like,', 'And'],
#  'Though,': ['maybe'],
#  'maybe': ['you', 'because,', 'because', 'a'],
#  'could': ['tell',
#   'pour',
#   'another',
#   'a',
#   'fix',
#   'be',
#   'be',
#   'see.',
#   'kinda',
#   'have',
#   'get',
#   'enjoy.',
#   'she',
#   'see',
#   'read',
#   'meet',
#   'have',
#   'hear'],
#  'tell': ['that', 'that', 'your', 'her', 'you'],
#  'from': ['the',
#   'my',
#   'the',
#   'the',
#   'the',
#   'the',
#   '’em.”',
#   'McDonald’s',
#   'office',
#   'her',
#   '1993',
#   'Friday',
#   'Rumours,',
#   'the'],
#  'moment': ['I', 'the', 'of'],
#  'walked': ['out',
#   'into',
#   'into',
#   'into,',
#   'in',
#   'into',
#   'in',
#   'into',
#   'in',
#   'into',
#   'in,',
#   'past',
#   'past',
#   'arm-in-arm',
#   'into'],
#  'stage.': ['I'],
#  'give': ['off', 'off', 'a', 'her', 'Petunia', 'him'],
#  'off': ['that', 'a', 'into', 'of', 'for', 'steam.”', 'the', 'of', 'and'],
#  'vibe.': ['Some'],
#  'people': ['give',
#   'before',
#   'think',
#   'at',
#   'say',
#   'in',
#   'would',
#   'are',
#   'who',
#   'get',
#   'are',
#   'you',
#   'cheating'],
#  'vibe': ['of…', 'is'],
#  'of…': ['Right'],
#  'Right': ['away,', 'this'],
#  'away,': ['they’re'],
#  'they’re': ['like,',
#   'always,',
#   'just',
#   'like,',
#   'like,',
#   'just',
#   'about',
#   'about',
#   'like,',
#   'becoming'],
#  '“Do': ['not', 'you', 'you'],
#  'not': ['fuck',
#   'really',
#   'gonna',
#   'you',
#   'allowed',
#   'even',
#   'enjoy',
#   'how',
#   'like',
#   'eating',
#   'a',
#   'gonna',
#   'gonna',
#   'to',
#   'fair,',
#   'how',
#   'freak',
#   'so',
#   'allowed',
#   'watching',
#   'serve',
#   'seen',
#   'need',
#   'lit',
#   'the',
#   'in',
#   'like',
#   'on',
#   'gonna'],
#  'fuck': ['with', 'his'],
#  'me.”': ['My', 'And', 'Like,'],
#  'My': ['vibe',
#   'wife',
#   'wife',
#   'brother',
#   'wife',
#   'title',
#   'lands',
#   'children',
#   'friends',
#   'friend,',
#   'friend’s',
#   'parents',
#   'parents',
#   'dad',
#   'dad',
#   'dad',
#   'dad',
#   'dad',
#   'only',
#   'mom',
#   'mom,',
#   'mom',
#   'feet',
#   'mom'],
#  '“Hey,': ['you',
#   'you',
#   'this',
#   'that’s',
#   'you’re',
#   'lady.',
#   'we',
#   'John,',
#   'remember',
#   'doesn’t',
#   'can',
#   'what',
#   'Finch,',
#   'I',
#   'can',
#   'can',
#   'Ellen,”',
#   'man,'],
#  'pour': ['soup'],
#  'soup': ['in'],
#  'my': ['lap',
#   'feet',
#   'wife.',
#   'wife.”',
#   'ticket',
#   'wife',
#   'girlfriend',
#   'wife!',
#   'wife!”',
#   'wife!”',
#   'dick',
#   'parents',
#   'day.',
#   'parents,',
#   'printing',
#   'dish.”',
#   'best',
#   'head,',
#   'wife,',
#   'wife',
#   'shirts',
#   'mortgage',
#   'mom.',
#   'imaginary',
#   'children.',
#   'wife!”',
#   'God.',
#   'trust.',
#   'opinion',
#   'thought',
#   '30s',
#   'apartment,”',
#   'lifetime.',
#   'life.',
#   'front',
#   'dick.”',
#   'mom',
#   'biters…',
#   'parents',
#   'best',
#   'dad',
#   'parents',
#   'dad',
#   'dad',
#   'dad',
#   'dad',
#   'entire',
#   'dad',
#   'hero.',
#   'brother',
#   'brother',
#   'brother',
#   'first',
#   'little',
#   'life?”',
#   'parents',
#   'parents',
#   'parents',
#   'mom',
#   'mom',
#   'mom',
#   'mom',
#   'dad,',
#   'parents',
#   'dad’s',
#   'dad',
#   'mom',
#   'First',
#   'mom,',
#   'mom',
#   'mom',
#   'friend,',
#   'mom,',
#   'sport',
#   'mom',
#   'son,',
#   'ten-year-old',
#   'advice.',
#   'entire',
#   'dad',
#   'dad',
#   'stomach.',
#   'eyes',
#   'dad',
#   'dad'],
#  'lap': ['and'],
#  'probably': ['apologize'],
#  'apologize': ['to'],
#  'you.”': ['When', 'It’s', 'I', 'And', 'And', '–', 'I', 'That’s', 'I', 'One'],
#  'When': ['I', 'you', 'they', 'I'],
#  'walk,': ['for', 'kind'],
#  'real,': ['my', 'Chicago,'],
#  'feet': ['go', 'from', 'were', 'tall.'],
#  'this.': ['I’m', 'They', 'Who', 'Really,', 'But'],
#  'I’m': ['so',
#   'actually',
#   'allowed',
#   'not',
#   'her',
#   'asking,',
#   'supervised.',
#   'filled',
#   'so',
#   'in',
#   'embarrassed',
#   'telling',
#   'not',
#   'just',
#   'sorry',
#   'quoting.',
#   'doing',
#   'giving',
#   'about',
#   'quoting,',
#   'a',
#   'walking',
#   'walking',
#   'quoting,',
#   'sorry',
#   'just',
#   'nine.”',
#   'not',
#   'definitely',
#   'gonna',
#   'gonna'],
#  'open': ['and', 'it', 'on', 'my'],
#  'vulnerable.': ['I'],
#  'doll': ['that'],
#  'point': ['out', 'at'],
#  'molestation': ['on.'],
#  'on.': ['“Show', '“Mmm,'],
#  '“Show': ['us'],
#  'us': ['on',
#   'with',
#   'to',
#   'down',
#   'were',
#   'going,',
#   'about',
#   'about',
#   'about',
#   'know'],
#  'this': ['white',
#   'way.”',
#   'expression',
#   'is',
#   'big,',
#   'stupid',
#   'under',
#   'is',
#   'look',
#   'entire',
#   'is',
#   'week’s',
#   'could',
#   'backyard',
#   'two-year-old',
#   'out',
#   'bottle',
#   'carton',
#   'experiment?”',
#   'best',
#   'is',
#   'guy’s',
#   'guy’s',
#   'family',
#   'is',
#   'nice',
#   'resort',
#   'Yellow',
#   'car…',
#   'year…',
#   'is',
#   'other',
#   'was',
#   'old',
#   'web',
#   'web',
#   'wet!',
#   'wet!”',
#   'woman',
#   'to',
#   'totally',
#   'to-do',
#   '2015',
#   'was',
#   'sort',
#   'time.',
#   'invitation',
#   'button'],
#  'white': ['comedian', 'man', 'van'],
#  'comedian': ['where', 'Dan'],
#  'where': ['the',
#   'I',
#   'you',
#   'we',
#   'the',
#   'she',
#   'you’re',
#   'she',
#   'you',
#   'Harrison',
#   'he’d'],
#  'man': ['touched', 'stumbling', 'wrote', 'who', 'who', 'we'],
#  'touched': ['you.”'],
#  'It’s': ['been',
#   'great,',
#   'just',
#   'a',
#   'just',
#   'just',
#   'like,',
#   'fun',
#   'a',
#   'just,',
#   'insane.',
#   'always',
#   'not',
#   'actually'],
#  'while': ['since', 'confusing', 'I', 'yelling,'],
#  'since': ['I’ve', 'then.'],
#  'home': ['to', 'that', 'that'],
#  'got': ['married',
#   'cheated',
#   'cheated',
#   'cheated',
#   'engaged,',
#   'married',
#   'all',
#   'this',
#   'schooled',
#   'offended',
#   'an',
#   'along',
#   'so',
#   'black',
#   'an',
#   'to',
#   'these',
#   'to',
#   'to',
#   'to',
#   'to',
#   'in',
#   'home',
#   'home'],
#  'married': ['since', 'my', 'is', 'by', 'by'],
#  'then.': ['Thank'],
#  'wife.': ['I'],
#  'love': ['saying', 'her.', 'to', 'real', 'us.'],
#  'saying': ['“my'],
#  '“my': ['wife.”'],
#  'wife.”': ['It', 'It’s', 'Being'],
#  'It': ['sounds',
#   'doesn’t',
#   'means,',
#   'was',
#   'sounds',
#   'was',
#   'was',
#   'was',
#   'matters',
#   'would',
#   'needs',
#   'would',
#   'was',
#   'was',
#   'had',
#   'wasn’t',
#   'did',
#   'starts',
#   'would',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'is',
#   'had'],
#  'sounds': ['so', 'like', 'good,'],
#  'adult.': ['“That’s'],
#  '“That’s': ['my', 'actually', 'exactly', 'great!”'],
#  'great,': ['you'],
#  'sound': ['like', 'editing', 'caught', 'like', 'like'],
#  'person.': ['I', 'And'],
#  'said': ['it',
#   '“priority',
#   'it',
#   'that.',
#   'to',
#   'vagina.',
#   'in',
#   'this',
#   'this',
#   'and'],
#  'it': ['even',
#   'that',
#   'changes',
#   'makes',
#   'weird',
#   'to',
#   'to',
#   'sort',
#   'to',
#   'works',
#   'was',
#   'has',
#   'off',
#   'constantly.',
#   'sound',
#   'sound',
#   'was',
#   'just',
#   'worse,',
#   'sounded',
#   'would’ve',
#   'doesn’t',
#   'just',
#   'wrong',
#   'recently.',
#   'would',
#   'Back',
#   'very',
#   'was',
#   'that',
#   'if',
#   'and',
#   'catching',
#   'constantly.',
#   'before.',
#   'out',
#   'was',
#   'in',
#   'is',
#   'was',
#   'in',
#   'meant',
#   'as',
#   'goes',
#   'starts',
#   'in',
#   'first',
#   'was',
#   'was',
#   'was',
#   'is',
#   'had',
#   'was',
#   'said,',
#   'was',
#   'was',
#   'was'],
#  'even': ['before',
#   'a',
#   'like',
#   'though',
#   'though',
#   'walk',
#   'like',
#   'though',
#   'in',
#   'do',
#   'think',
#   'be',
#   'the'],
#  'before': ['we',
#   'I',
#   'anyone',
#   'Petunia.',
#   'my',
#   'we',
#   'we',
#   'children',
#   'children',
#   'we',
#   'would',
#   'I'],
#  'we': ['were',
#   'were',
#   'were',
#   'got',
#   'grew',
#   'go',
#   'love',
#   'all',
#   'solve?',
#   'have',
#   'take',
#   'go,',
#   'just',
#   'didn’t',
#   'walked',
#   'go',
#   'said,',
#   'don’t',
#   'don’t',
#   'all?',
#   'would',
#   'wanted.',
#   'should',
#   'would',
#   'met',
#   'were',
#   'got',
#   'don’t',
#   'didn’t',
#   'call',
#   'were',
#   'were',
#   'went',
#   'were',
#   'were',
#   'didn’t',
#   'both',
#   'were',
#   'were',
#   'get',
#   'see',
#   'got',
#   'started',
#   'have',
#   'wanted',
#   'kept',
#   'had',
#   'only',
#   'don’t',
#   'don’t',
#   'don’t',
#   'definitely',
#   'all',
#   'all',
#   'have',
#   'eat',
#   'all',
#   'all',
#   'walk',
#   'saw'],
#  'were': ['married.',
#   'just',
#   'once',
#   'getting',
#   'like,',
#   'supposed',
#   'known',
#   'filled,',
#   'right',
#   'like,',
#   'like…',
#   'you',
#   'free',
#   'special.',
#   'like,',
#   'like,',
#   'all',
#   'just',
#   'little',
#   'terrible.',
#   'going',
#   'little',
#   'like,',
#   'the',
#   'criminals.',
#   'not',
#   'really',
#   'in',
#   'like,',
#   'at',
#   'like…',
#   'like…',
#   'like,',
#   'like,',
#   'leaving',
#   'encouraged',
#   'dating',
#   'a',
#   'gonna',
#   'not'],
#  'married.': ['We', 'This', 'I’ve'],
#  'We': ['were',
#   'have',
#   'had',
#   'tell',
#   'go,',
#   'have',
#   'would',
#   'don’t,',
#   'were',
#   'were',
#   'thought…',
#   'thought',
#   'thought',
#   'weren’t',
#   'were',
#   'were',
#   'only',
#   'kind',
#   'had',
#   'see',
#   'started',
#   'were',
#   'don’t',
#   'once',
#   'have',
#   'walked',
#   'pushed',
#   'land'],
#  'dating,': ['and'],
#  'once': ['getting', 'an', 'had,', 'shushed', 'went', 'on', 'walking'],
#  'getting': ['on', 'on', 'milk'],
#  'an': ['airplane,',
#   'ex',
#   'old',
#   'entire',
#   'altar',
#   'altar',
#   'altar',
#   'exorcist',
#   'office.”',
#   'on-fire',
#   'elevator,',
#   'arrangement',
#   'anthropologist.',
#   'X',
#   'acceptable',
#   'idea…',
#   'award.',
#   'illegal',
#   'office',
#   'office',
#   'ivory',
#   'assistant',
#   'assistant.',
#   'old',
#   'old,',
#   'album'],
#  'airplane,': ['and'],
#  'Anna’s': ['ticket'],
#  'ticket': ['didn’t', 'said'],
#  'didn’t': ['say',
#   'kill',
#   'even',
#   'work',
#   'buy',
#   'mean',
#   'mean',
#   'actually',
#   'want',
#   'even',
#   'like',
#   'trust',
#   'get',
#   'care',
#   'know',
#   'know'],
#  'say': ['anything',
#   'this.',
#   'that',
#   'it.',
#   'to',
#   'when',
#   'in',
#   'they',
#   'to',
#   'just',
#   'something',
#   'mean',
#   'that'],
#  'anything': ['and', 'you', 'at'],
#  '“priority': ['access.”'],
#  'access.”': ['It'],
#  'doesn’t': ['matter', 'matter', 'matter', 'get', 'get', 'anyone'],
#  'matter': ['why.', 'in', 'what'],
#  'why.': ['But'],
#  'But': ['we',
#   'also,',
#   'now,',
#   'I',
#   'they',
#   'I',
#   'I',
#   'then',
#   'also,',
#   'that',
#   'in',
#   'when',
#   'I',
#   'he',
#   'one',
#   'then',
#   'it’s',
#   'with',
#   'rather',
#   'Mr.',
#   'such',
#   'by',
# ...
#   'estate',
#   'person',
#   'thrill',
#   'Who’s',
#   'cool'],
#  'here.': ['You’re', 'This', 'They', 'Take'],
#  'lucky': ['to'],
#  'have.': ['“Roping'],
#  '“Roping': ['in'],
#  'cows': ['and', 'total,'],
#  'known': ['for,'],
#  'for,': ['John.”'],
#  'John.”': ['By', 'My', 'And', 'And', 'And'],
#  'By': ['the', '2029,'],
#  'most': ['liberal', 'famous', 'exciting'],
#  'liberal': ['of'],
#  'estimates,': ['there'],
#  'total,': ['several'],
#  'several': ['unmilked,'],
#  'unmilked,': ['and…'],
#  'bulls,': ['and'],
#  'bought…': ['They'],
#  'assume': ['it.'],
#  'search': ['your'],
#  'name,': ['the', 'right?'],
#  'third': ['thing', 'option'],
#  'come': ['up', 'on!”', 'on!', 'into'],
#  '“John': ['Mulaney', 'Edmund'],
#  'Mulaney': ['bull?”'],
#  'bull?”': ['And'],
#  'bought': ['the', 'a', 'a', 'outside'],
#  'nobody': ['would', 'no'],
#  'They’ll': ['still'],
#  'still': ['say', 'have,', 'awake,'],
#  'who,': ['they'],
#  'side,': ['total'],
#  'total': ['matador,'],
#  'matador,': ['but…'],
#  'but…': ['But,', '…', 'There’s', 'My', 'No,', 'Kimble,'],
#  'But,': ['for', 'go,', 'no,', 'but,'],
#  'Chicago,': ['why'],
#  'why': ['buy', 'he', 'he'],
#  'cow?': ['Let’s', 'Because'],
#  'Let’s': ['be', 'keep', 'talk', 'go.”'],
#  'real.': ['Why'],
#  'Why': ['buy', 'does'],
#  'Because': ['you', 'that’s', 'that', 'the'],
#  'her.': ['You', 'It', 'She’s', 'And', 'And', 'She’s'],
#  'yeah…': ['Sure,'],
#  'Sure,': ['she’s'],
#  'bossy': ['little'],
#  'Jew,': ['but…'],
#  'she': ['takes',
#   'gets',
#   'was',
#   'pointed',
#   'said,',
#   'showed',
#   'said,',
#   'walked',
#   'had',
#   'goes,',
#   'picked',
#   'was',
#   'says',
#   'went,',
#   'a',
#   'was',
#   'had',
#   'said,',
#   'hung',
#   'have',
#   'was',
#   'had',
#   'could',
#   'said',
#   'said,',
#   'said',
#   'was',
#   'lost',
#   'goes,',
#   'has',
#   'pushes',
#   'goes,'],
#  'takes': ['care'],
#  'wanna': ['be', 'say,', 'know', 'know', 'die', 'say', 'tell'],
#  'stumbling': ['around,'],
#  'around,': ['like,'],
#  'any': ['loose', 'children,', 'book,'],
#  'loose': ['milk?”'],
#  'milk?”': ['My'],
#  'Jewish.': ['She’s'],
#  'She’s': ['a', 'enchanting.”', 'a', 'a', 'just', 'smoking', 'watching'],
#  'New': ['York', 'York', 'York', 'York.', 'York.', 'York', 'York'],
#  'York': ['Jew.', 'City.', 'City.', 'Times.', 'Times.'],
#  'Jew.': ['I'],
#  'it!': ['Now,'],
#  'raised': ['Catholic.'],
#  'Catholic.': ['I', 'I'],
#  'everything': ['about', 'to'],
#  'me.': ['My', 'I', 'But', 'I', 'This', 'You’re', 'Mary,', 'I', 'I'],
#  'Jewish,': ['I'],
#  'Catholic,': ['so', 'I'],
#  'friend.': ['Being'],
#  'friend': ['is', 'in', 'is', 'who’s,', 'named'],
#  'beautiful': ['ceremony'],
#  'ceremony': ['that'],
#  'alienates': ['both'],
#  'both': ['families’', 'have'],
#  'families’': ['religions,'],
#  'religions,': ['while'],
#  'confusing': ['the'],
#  'elderly': ['people'],
#  'wedding.': ['“What’s'],
#  '“What’s': ['the'],
#  'name': ['of', 'three', 'was'],
#  'bishop?”': ['“That’s'],
#  'actually': ['stand-up', 'glad', 'have', 'wanna', 'happened.', 'the'],
#  'stand-up': ['comedian'],
#  'Dan': ['Levy.'],
#  'Levy.': ['He'],
#  'He': ['was',
#   'just',
#   'had',
#   'once',
#   'owned',
#   'had',
#   'had',
#   'did',
#   'would',
#   'always',
#   'let',
#   'goes,',
#   'was'],
#  'host': ['of'],
#  'MTV’s': ['Your'],
#  'Your': ['Face', 'opinion', 'kid'],
#  'Face': ['or'],
#  'Mine?”': ['I'],
#  'saw': ['a', 'the', 'a'],
#  'Catholic': ['weddings,', 'Church.'],
#  'weddings,': ['though,'],
#  'though,': ['because'],
#  'altar': ['boy…', 'boy', 'boy', 'boy', 'boy', 'to'],
#  'boy…': ['And'],
#  'hush': ['falls'],
#  'falls': ['over', 'open'],
#  'Isn’t': ['it', 'anyone'],
#  'weird': ['how', 'movie.', 'thing,', 'shit'],
#  'became': ['a', 'special.', 'a', 'friends.', 'like'],
#  'scandalous': ['thing?'],
#  'thing?': ['That'],
#  'boring': ['shit', 'gig,'],
#  'shit': ['I', 'you', 'at', 'you', 'to'],
#  'had': ['to',
#   'church.',
#   'to',
#   'a',
#   'his',
#   'an',
#   'violated',
#   'been',
#   'said',
#   'walked',
#   'been',
#   'no',
#   'a',
#   'no',
#   'to',
#   'to',
#   'access?”',
#   'that',
#   'a',
#   'a',
#   'not',
#   'an',
#   'planted',
#   'other',
#   'next',
#   'suspenders,',
#   'a',
#   'a',
#   'a',
#   'an',
#   'an',
#   'been',
#   'his',
#   'said.',
#   'gone',
#   'Terminator',
#   'to',
#   'paused',
#   'gone',
#   'very',
#   'hired',
#   'a',
#   'been',
#   'been'],
#  'weekends.': ['But'],
#  'saying,': ['“I'],
#  'French': ['maid', 'bulldog', 'assholes', 'bastards'],
#  'maid': ['for'],
#  'period': ['of'],
#  'time.': ['I', 'She', 'I', 'And', 'That', 'And'],
#  'treated': ['well'],
#  'well': ['in', 'with', 'enough'],
#  'day.': ['I', 'She', 'We', 'His', 'I', 'The', 'She', 'I', 'It', 'I', 'And'],
#  'worked': ['for', 'at'],
#  'variety': ['of'],
#  'sirs.”': ['No,'],
#  'boy': ['was', 'at', 'in', 'said,', 'and', 'has'],
#  'gig,': ['you'],
#  'You’d': ['serve'],
#  'serve': ['Mass', 'weddings', 'hard'],
#  'Mass': ['and', 'and'],
#  'you’d': ['serve'],
#  'weddings': ['sometimes.'],
#  'sometimes.': ['My'],
#  'brother': ['was', 'came,', 'up', 'was'],
#  'wedding,': ['and'],
#  'standing': ['there', 'at', 'there'],
#  'big,': ['packed', 'like,', 'fat', 'like,'],
#  'packed': ['church', 'with', 'with', 'with', 'with', 'with'],
#  'church': ['in', 'anymore.', 'and', 'where', 'ever,'],
#  'Chicago': ['where', 'celebrities.', 'Democrats.'],
#  'up.': ['And', 'Think'],
#  'bride': ['was', 'got'],
#  'coming': ['down', 'to'],
#  'down': ['the',
#   'the',
#   'empty',
#   'month',
#   'and',
#   'in',
#   'the',
#   'for',
#   '31st',
#   '31st,',
#   'fat',
#   'so'],
#  'aisle,': ['and', 'and'],
#  'organ': ['was'],
#  'playing,': ['and'],
#  'pews': ['were'],
#  'filled,': ['and'],
#  'altar,': ['and'],
#  'groom': ['lifted'],
#  'lifted': ['the'],
#  'veil': ['off'],
#  'bride,': ['and'],
#  'right': ['at', 'next', 'at', 'before', 'now.”', 'at', 'away.'],
#  'other': ['altar', 'way', 'jobs', 'cubicle.', 'cubicle.', 'hand,', 'shoe'],
#  '“Aw,': ['she’s', 'she’s', 'she’s'],
#  'ugly.”': ['And'],
#  'looked,': ['and'],
#  'video': ['camera.', 'games'],
#  'camera.': ['And'],
#  'awful,': ['but'],
#  'wouldn’t': ['you', 'even'],
#  'million': ['dollars', 'kisses'],
#  'dollars': ['to'],
#  'wedding': ['video?'],
#  'video?': ['It'],
#  'best': ['moment',
#   'friend',
#   'friend',
#   'friend?',
#   'friend',
#   'friend,',
#   'movie',
#   'friend.”',
#   'night'],
#  'stupid': ['woman’s', 'parents.'],
#  'woman’s': ['life,'],
#  'life,': ['and'],
#  'walking': ['down', 'into', 'down', 'down', 'towards'],
#  'organ’s': ['like…'],
#  'her': ['betrothed,',
#   'to',
#   'face',
#   'a',
#   'that',
#   'dish,',
#   'Paul',
#   'Uncle',
#   'daughter',
#   'cubicle.',
#   'daughter,',
#   'phone',
#   'call,',
#   'well',
#   '50s,',
#   'and',
#   'and',
#   'with',
#   'dorm.',
#   'roommate',
#   'chance',
#   'date…'],
#  'betrothed,': ['and'],
#  'unveils': ['her'],
#  'world': ['and', 'making', 'with'],
#  'eyes': ['of', 'and', 'to'],
#  'God.': ['And', 'That’s'],
#  'second,': ['for'],
#  'reason': ['at'],
#  'all,': ['some'],
#  'Cheeto-fingered,': ['rat-mustached,'],
#  'rat-mustached,': ['13-year-old'],
#  '13-year-old': ['prick'],
#  'decides': ['to'],
#  'go,': ['“Aw,',
#   'tell',
#   '“Hey,',
#   '“Mmm,',
#   '“Let’s',
#   '“Stop',
#   '“Oh,',
#   '“I',
#   '“What',
#   '“No,',
#   '“No,'],
#  'ugly!”': ['Hopefully'],
#  'Hopefully': ['the'],
#  'videographer': ['knew'],
#  'editing': ['so'],
#  'fix': ['it'],
#  'beautiful.': ['She’s'],
#  'enchanting.”': ['I'],
#  'went': ['on',
#   'outside',
#   'with',
#   'back',
#   'to',
#   'into',
#   'to',
#   'to',
#   'was',
#   'to',
#   'to',
#   'with',
#   'up',
#   'in'],
#  'Christmas': ['Eve'],
#  'Eve': ['with'],
#  'parents,': ['’cause', 'and'],
#  'lie': ['to'],
#  'parents.': ['So…', 'And'],
#  'under': ['control.”', 'a', 'one'],
#  'control.”': ['And'],
#  'schooled': ['because'],
#  'introduced': ['a'],
#  'bunch': ['of', 'of'],
#  'new': ['shit.', 'house.'],
#  'shit.': ['No,'],
#  'going': ['through',
#   'through',
#   'here.',
#   'to',
#   'to',
#   'to',
#   'down',
#   'on',
#   'to',
#   'to'],
#  'through': ['Mass', 'that', 'the', 'the'],
#  'batting,': ['like,'],
#  '.400.': ['And'],
#  'middle': ['of'],
#  'Mass,': ['the'],
#  'priest': ['said,', 'says,', 'was'],
#  '“Peace': ['be', 'be'],
#  'everyone': ['said,', 'could', 'at', 'who', 'gets'],
#  '“And': ['with',
#   'also',
#   'also',
#   'with',
#   'also',
#   'also',
#   'also',
#   'also.”',
#   'when',
#   'I’m'],
#  'spirit.”': ['And', 'Because'],
#  'pre-Y2K': ['asshole'],
#  'asshole': ['going,'],
#  'going,': ['“And', '“Look,'],
#  'also': ['with',
#   'with',
#   'with',
#   'with',
#   'you',
#   'you',
#   'a',
#   'satisfies',
#   'a',
#   'going'],
#  'What?': ['Huh?', 'Huh?', 'When?'],
#  'Huh?': ['What?', 'What?'],
#  'When?': ['When?”'],
#  'When?”': ['For'],
#  'For': ['those', 'those'],
#  'aren’t': ['Catholic,'],
#  'exclude': ['you,', 'you,'],
#  'you,': ['even', 'but…', 'on', 'and'],
#  'There’s': ['a'],
#  'part': ['in'],
#  'says,': ['“Peace', '“He', '“Why?', '“Fine!', '“Hey,', '“The'],
#  'many,': ['many'],
#  'many': ['years,', 'women'],
#  'years,': ['we', 'like,'],
#  'said…': ['–'],
#  '–': ['“And',
#   'Very',
#   '“Have',
#   '“And',
#   'What’s',
#   'Sam.',
#   '“Hush!”',
#   '“You’re'],
#  'Very': ['good.', 'early', 'dirty,'],
#  'changed': ['it', 'that,'],
#  'needed': ['revamping', 'the', 'someone'],
#  'revamping': ['in'],
#  'Church.': ['That'],
#  'squeaky': ['wheel'],
#  'wheel': ['that'],
#  'grease.': ['In'],
#  'In': ['Rome,'],
#  'Rome,': ['they'],
#  '“Let’s': ['see.', 'pretend.', 'talk.'],
#  'see.': ['What', 'Kids'],
#  'What': ['problems', 'is', 'a', 'are', 'do', 'the', 'accent'],
#  'problems': ['can'],
#  'solve?': ['Problem'],
#  'Problem': ['one.'],
#  'one.': ['No.”', 'We', 'Unless'],
#  'No.”': ['I’m'],
#  'glad': ['they'],
#  'that,': ['though.', 'no', 'uh…', 'like,', 'but'],
#  'though.': ['I'],
#  'liked': ['“And'],
#  'found': ['that', 'out'],
#  'clunky.': ['“And'],
#  'talk.': ['–', 'Let’s'],
#  '“Have': ['a'],
#  'nice': ['day.”', 'man’s'],
#  'day.”': ['–'],
#  'one.”': ['It’s'],
#  'bit': ['wrong,', 'my', 'of'],
#  'wrong,': ['isn’t', 'my'],
#  'isn’t': ['it?', 'that'],
#  'it?': ['It’s', 'Because'],
#  'off.': ['Like,', '‘Cause'],
#  'someone’s': ['like,'],
#  '“Nothing': ['much.”'],
#  'much.”': ['And'],
#  'Never': ['begin'],
#  'sentence': ['with'],
#  'also.”': ['You'],
#  'immediately': ['sound', 'turn'],
#  'caught': ['off-guard.'],
#  'off-guard.': ['It'],
#  'ever,': ['like,'],
#  'weren’t': ['expecting', 'special', 'friends.'],
#  'expecting': ['it.'],
#  'we’ve': ['ever'],
#  'church.': ['I'],
#  '‘Peace': ['be'],
#  "you.'”": ['And'],
#  '“What?': ['Oh.'],
#  'Oh.': ['Uh,'],
#  'yeah.': ['And'],
#  'some.”': ['“Hey,'],
#  '2,000': ['years.'],
#  'years.': ['And', 'The', 'And'],
#  'change': ['it', 'because'],
#  'trick': ['John.”'],
#  'children,': ['we'],
#  'dog.': ['We', 'We'],
#  'puppy': ['named', 'that’s'],
#  'named': ['Petunia.', 'Marty,', 'Biff,', 'Mischa', 'Mary.', 'Bill'],
#  'tiny': ['little'],
#  'bulldog': ['puppy.'],
#  'puppy.': ['I'],
#  'bulldog,': ['’cause'],
#  'baby': ['that',
#   'more',
#   'will',
#   'pointed',
#   'points',
#   'and',
#   'had',
#   'had',
#   'had'],
#  'grandma.': ['Her'],
#  'Her': ['body', 'phone'],
#  'body': ['is'],
#  'young,': ['her'],
#  'face': ['is', 'and'],
#  'as': ['old',
#   'time.',
#   'long',
#   'it',
#   'much',
#   'Powder',
#   'to',
#   'mad',
#   'that',
#   'a',
#   'if',
#   'a',
#   'it',
#   'Bill',
#   'a',
#   'her',
#   'Dr.',
#   'a',
#   'president.'],
#  'She': ['definitely',
#   'always',
#   'said',
#   'does',
#   'said,',
#   'said,',
#   'said,',
#   'said,',
#   'eats',
#   'said,',
#   'said,',
#   'hinted',
#   'showed',
#   'goes,',
#   'said,',
#   'came',
#   'studies',
#   'told',
#   'was',
#   'was',
#   'goes,'],
#  'definitely': ['saw', 'don’t', 'never'],
#  'Nazis': ['march'],
#  'march': ['into'],
#  'Paris.': ['She'],
#  'gives': ['me', 'you'],
#  'seen,': ['you'],
#  'cocksucker.': ['You', 'Dish,'],
#  'idea.': ['The'],
#  'The': ['Gestapo',
#   'woman',
#   'baby’s',
#   'rights',
#   'dad’s',
#   'one',
#   'weirdest',
#   'bad',
#   'rain.',
#   'things',
#   'Fugitive,',
#   'Comeback',
#   'New',
#   'New'],
#  'Gestapo': ['threw'],
#  'threw': ['my'],
#  'printing': ['press'],
#  'press': ['into'],
#  'river.': ['But,'],
#  'fucking': ['jokes.', 'markers.”'],
#  'jokes.': ['Bring'],
#  'Bring': ['me'],
#  'dish.”': ['She'],
#  'Petunia…': ['Petunia'],
#  'Petunia': ['is', 'is', 'that', 'her'],
#  'world.': ['I'],
#  'kisses': ['a'],
#  'me,': ['and', 'she', 'and', 'I', 'my'],
#  'barks': ['at'],
#  'bites': ['me'],
#  'day': ['long.', 'she', 'you'],
#  'long.': ['We'],
#  'dog': ['trainer'],
#  'trainer': ['into', 'came'],
#  'bad': ['dog.', 'at', 'mom?”', 'guy', 'for'],
#  'dog.”': ['So,', 'She'],
#  'So,': ['the',
#   'we’d',
#   'we’re',
#   'we',
#   'every',
#   'we’re',
#   'I',
#   'when',
#   'my',
#   'my',
#   'I',
#   'that',
#   'my',
#   'that',
#   'my',
#   'Kimble',
#   'we',
#   'what',
#   'here’s'],
#  'came': ['into', 'over', 'in', 'to', 'into'],
#  'apartment.': ['Sorry,'],
#  'Sorry,': ['didn’t', 'the'],
#  'walk': ['into',
#   'off.',
#   'in',
#   'away',
#   'them',
#   'ya',
#   'ya',
#   'ya',
#   'ya',
#   'ya',
#   'in,',
#   'in,',
#   'into'],
#  'apartment,': ['walked'],
#  'threshold': ['and'],
#  'went,': ['“Oh,', '“No!”', '“All', '“Hey!'],
#  'Like': ['she', 'we’re', 'an', 'Back', 'it’s', 'old,'],
#  'exorcist': ['or'],
#  'something.': ['She', 'He', 'Mr.'],
#  'is.”': ['She'],
#  '“Petunia': ['has', 'eats'],
#  'become': ['the', 'the'],
#  'alpha': ['of', 'of', 'of'],
#  'house.”': ['And', 'And', 'I'],
#  'pointed': ['at', 'at', 'at'],
#  '“You': ['are', 'need', 'know,', 'switched', 'switched', 'can', 'have'],
#  'longer': ['the'],
#  'back': ['of', 'in', 'in', 'in', 'then,', 'of'],
#  'head,': ['I', 'and'],
#  'turned': ['to', 'around', 'around'],
#  'wife,': ['I'],
#  'pretend.': ['It’ll'],
#  'It’ll': ['be'],
#  'fun.': ['Yes…'],
#  'Yes…': ['My'],
#  'title': ['of'],
#  'alpha,': ['which'],
#  'which': ['I', 'is', 'is,', 'Mr.', 'was,'],
#  'had,': ['how'],
#  'reclaim': ['it?'],
#  'existed': ['at'],
#  'time.”': ['She'],
#  'show': ['dominance', 'up', 'that', 'at'],
#  'dominance': ['over'],
#  'puppy.”': ['These'],
#  'These': ['are', 'are'],
#  'that?”': ['She'],
#  'let': ['me', 'him', 'us'],
#  'ask': ['you'],
#  'Who': ['eats', 'could'],
#  'eats': ['dinner', 'dinner', 'dinner', 'before'],
#  'dinner': ['first,', 'first.', 'at', 'first.', 'at', 'whenever', 'before'],
#  'first,': ['you'],
#  'Petunia?”': ['I'],
#  'first.': ['She', 'Because'],
#  '5:00': ['p.m.,'],
#  'p.m.,': ['’cause'],
#  'foot': ['long'],
#  'two': ['years', 'feet', 'always', 'in', 'sisters', 'times', 'times'],
#  'old.”': ['She'],
#  'eat': ['dinner', 'dinner', 'dinner', 'enough', 'fries!”'],
#  'king': ['eats', 'I'],
#  'anyone': ['else', 'else', 'in', 'wanna', 'curious…', 'would.'],
#  'eats.”': ['Oh,'],
#  'yes,': ['and'],
#  'mighty': ['king'],
#  'be,': ['eating'],
#  'eating': ['dinner', 'dinner.”', 'dinner,'],
#  '4:45': ['in'],
#  'afternoon.': ['“Look', 'Mr.', 'And'],
#  '“Look': ['upon'],
#  'upon': ['your'],
#  'sovereign,': ['Petunia,'],
#  'Petunia,': ['and'],
#  'tremble.': ['My'],
#  'lands': ['stretch'],
#  'stretch': ['across'],
#  'across': ['this'],
#  'bedroom,': ['and'],
#  'whenever': ['I'],
#  'choose,': ['as'],
#  'works': ['for'],
#  'schedule': ['of'],
#  '“Now,': ['you', 'I’m'],
#  'convince': ['Petunia'],
#  'eaten.”': ['So…'],
#  'month,': ['I'],
#  'not…': ['before'],
#  'dish,': ['we'],
#  'empty': ['bowls'],
#  'bowls': ['and'],
#  'spoons,': ['and'],
#  'front': ['of', 'of', 'door', 'of', 'of', 'of', 'and', 'of'],
#  'her,': ['we', 'she', 'my'],
#  '“Mmm,': ['dinner.', 'we’re'],
#  'dinner.': ['Mmm,'],
#  'Mmm,': ['good'],
#  'dinner.”': ['Like', 'Meanwhile,'],
#  'space': ['aliens'],
#  'aliens': ['in'],
#  'play': ['about', 'his'],
#  'beings': ['that'],
#  'wrote,': ['but'],
#  'work': ['that', 'in', 'to'],
#  'hard': ['on.', 'time.'],
#  'Meanwhile,': ['Petunia’s'],
#  'Petunia’s': ['just'],
#  'staring': ['at'],
#  'Paul': ['Giamatti'],
#  'Giamatti': ['face,'],
#  'face,': ['like…'],
#  '“You’re': ['not', 'promoted.”'],
#  'dinner,': ['cocksucker.'],
#  'Dish,': ['now.”'],
#  'dog,': ['and'],
#  'house.': ['We', 'It', 'A', 'She’d'],
#  'built': ['in'],
#  '’20s,': ['but'],
#  'flipped': ['in'],
#  '2014.': ['Which'],
#  'means': ['it’s'],
#  'haunted,': ['but'],
#  'lovely': ['kitchen', 'day.'],
#  'kitchen': ['backsplash.', 'one'],
#  'backsplash.': ['Actually,'],
#  'Actually,': ['we'],
#  'A': ['bank', 'Beach', 'disgraced', 'Beautiful', 'very', 'real'],
#  'bank': ['bought', 'came'],
#  'house,': ['and', 'but', '’cause', 'you'],
#  'shirts': ['and'],
#  'pants': ['there'],
#  'pay': ['it', 'in'],
#  '30': ['years.', 'years.'],
#  'showed': ['me', 'me', 'them'],
#  'mortgage': ['broken'],
#  'broken': ['down', 'I'],
#  'month': ['by', 'for'],
#  '“So,': ['for', 'there’s', 'this', 'how’d'],
#  'instance,': ['this'],
#  'you’ll': ['pay'],
#  'July': ['of'],
#  '2029.”': ['And'],
#  'burst': ['out'],
#  'laughing.': ['I'],
#  '“2029?': ['That’s'],
#  ...}

# %%
import random

def generate_sentence(chain, count=20):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '!'
    return(sentence)

# %%
generate_sentence(john_dict)
# Out:
# 'Bedroom, and knowingly says, “Fine! I’ll take John.” And the cow is absolutely true. My friend’s a big, packed with!'
